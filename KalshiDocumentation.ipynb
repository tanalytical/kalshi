# %%
import sys #guarantees same kernel
# !{sys.executable} -m pip install pandas
# !{sys.executable} -m pip install requests

# %% [markdown]
# #### Quick start Kalshi API
# https://docs.kalshi.com/getting_started/terms/
#
# - **Market:** The tradable binary contract (ticker, bid/ask, volume, orderbook, candles, etc.).
# - **Event:** The specific real-world occurrence (e.g., one game date/matchup); contains one or more markets.
# - **Series:** A collection of related events that share the same rules/structure (same contract type).
#   - **Example:** “NBA game winner” as a repeating template for every game.
#
# - **Kalshi data has the following hierarchy (3 levels):**
#   - **Series:** `KXNBAGAME` (series ticker in the API; case-sensitive)
#     - **Event:** `kxnbagame-26feb24nykcle`
#       - **Markets:** one or more market tickers inside the event (often one per team for “winner” style events)
#
# - **Common market fields you’ll see:**
#   - `yes_bid`, `yes_ask`, `last_price`, `volume`, `open_interest`, `orderbook`, `candlesticks`, `trades`

# %% [markdown]
# Let's start by fetching information about the KXNBAGAME series. We'll use the Get Series endpoint.

# %%
import requests

# Get series information for KXNBAGAME
url = "https://api.elections.kalshi.com/trade-api/v2/series/KXNBAGAME"
response = requests.get(url)
series_data = response.json()

print(f"Series Title: {series_data['series']['title']}")
print(f"Frequency: {series_data['series']['frequency']}")
print(f"Category: {series_data['series']['category']}")
# Out:
# Series Title: Professional Basketball Game
# Frequency: custom
# Category: Sports

# %% [markdown]
# Now that we have the series information, lets get the markets for this series

# %%
# Get all open markets for the KXNBAGAME series
markets_url = f"https://api.elections.kalshi.com/trade-api/v2/markets?series_ticker=KXNBAGAME&status=open"
markets_response = requests.get(markets_url)
markets_data = markets_response.json()

print(type(markets_data))
print(list(markets_data["markets"][0].keys()))
# Out:
# <class 'dict'>
# ['can_close_early', 'close_time', 'created_time', 'custom_strike', 'early_close_condition', 'event_ticker', 'expected_expiration_time', 'expiration_time', 'expiration_value', 'fractional_trading_enabled', 'last_price', 'last_price_dollars', 'latest_expiration_time', 'liquidity', 'liquidity_dollars', 'market_type', 'no_ask', 'no_ask_dollars', 'no_bid', 'no_bid_dollars', 'no_sub_title', 'notional_value', 'notional_value_dollars', 'open_interest', 'open_interest_fp', 'open_time', 'previous_price', 'previous_price_dollars', 'previous_yes_ask', 'previous_yes_ask_dollars', 'previous_yes_bid', 'previous_yes_bid_dollars', 'price_level_structure', 'price_ranges', 'response_price_units', 'result', 'rules_primary', 'rules_secondary', 'settlement_timer_seconds', 'status', 'strike_type', 'subtitle', 'tick_size', 'ticker', 'title', 'updated_time', 'volume', 'volume_24h', 'volume_24h_fp', 'volume_fp', 'yes_ask', 'yes_ask_dollars', 'yes_bid', 'yes_bid_dollars', 'yes_sub_title']

# %%
# Display the first market in the series as a df
import pandas as pd

df = pd.json_normalize(markets_data["markets"][0])
df.head()
#df.columns.tolist() # list column names
# Out:
#    can_close_early            close_time                 created_time  \
# 0             True  2026-03-12T03:00:00Z  2026-02-23T17:02:05.873203Z
#
#                                early_close_condition             event_ticker  \
# 0  This market will close and expire after a winn...  KXNBAGAME-26FEB25BOSDEN
#
#   expected_expiration_time       expiration_time expiration_value  \
# 0     2026-02-26T06:00:00Z  2026-03-12T03:00:00Z
#
#    fractional_trading_enabled  last_price  ... volume volume_24h  \
# 0                       False           0  ...      0          0
#
#    volume_24h_fp volume_fp yes_ask  yes_ask_dollars yes_bid  yes_bid_dollars  \
# 0           0.00      0.00      63           0.6300      51           0.5100
#
#   yes_sub_title         custom_strike.basketball_team
# 0        Denver  ba2cb6be-9827-46a8-8e6f-d8661307ba77
#
# [1 rows x 55 columns]

# %% [markdown]
# The fields describe: what the contract is, when it trades/closes, and the current order book / trading stats.
#
# ##### In any market with an order book:
# - **Bid** = the best price someone is currently offering to buy at.
# - **Ask** = the best price someone is currently offering to sell at.
#
# - So for **YES** in your output:
#     - `yes_bid`: 46 → highest buyer is willing to pay 46¢ for YES ( $0.46 )
#     - `yes_ask`: 63 → lowest seller is asking 63¢ for YES ( $0.63 )
#     - `no_bid`, no_ask: best buy / best sell for NO
# - For **NO**:
#     - `no_bid`: 37 ( $0.37 )
#     - `no_ask`: 54 ( $0.54 )
#
# ##### Activity / liquidity
# - `volume`, `volume_24h`: number of contracts traded total / last 24h
# - `open_interest`: how many contracts are currently open (held) and not settled

# %%
# quick look at all the markets in this series
print(f"\nActive markets in KXNBAGAME series:")
for market in markets_data['markets']:
    print(f"- {market['ticker']}: {market['title']}")
    print(f"  Event: {market['event_ticker']}")
    print(f"  Yes Bid: {market['yes_bid']}¢ | Volume: {market['volume']}")
    print(f"  Yes Ask: {market['yes_ask']}¢ | Volume: {market['volume']}")
    print()
# Out:
# Active markets in KXNBAGAME series:
# - KXNBAGAME-26FEB25BOSDEN-DEN: Boston at Denver Winner?
#   Event: KXNBAGAME-26FEB25BOSDEN
#   Yes Price: 51¢ | Volume: 0
#   Yes Price: 63¢ | Volume: 0
#
# - KXNBAGAME-26FEB25BOSDEN-BOS: Boston at Denver Winner?
#   Event: KXNBAGAME-26FEB25BOSDEN
#   Yes Price: 37¢ | Volume: 11
#   Yes Price: 39¢ | Volume: 11
#
# - KXNBAGAME-26FEB25SACHOU-SAC: Sacramento at Houston Winner?
#   Event: KXNBAGAME-26FEB25SACHOU
#   Yes Price: 14¢ | Volume: 0
#   Yes Price: 18¢ | Volume: 0
#
# - KXNBAGAME-26FEB25SACHOU-HOU: Sacramento at Houston Winner?
#   Event: KXNBAGAME-26FEB25SACHOU
#   Yes Price: 77¢ | Volume: 20
#   Yes Price: 81¢ | Volume: 20
#
# - KXNBAGAME-26FEB25CLEMIL-MIL: Cleveland at Milwaukee Winner?
#   Event: KXNBAGAME-26FEB25CLEMIL
#   Yes Price: 22¢ | Volume: 3
#   Yes Price: 32¢ | Volume: 3
#
# - KXNBAGAME-26FEB25CLEMIL-CLE: Cleveland at Milwaukee Winner?
#   Event: KXNBAGAME-26FEB25CLEMIL
#   Yes Price: 67¢ | Volume: 59
#   Yes Price: 71¢ | Volume: 59
#
# - KXNBAGAME-26FEB25SASTOR-TOR: San Antonio at Toronto Winner?
#   Event: KXNBAGAME-26FEB25SASTOR
#   Yes Price: 31¢ | Volume: 0
#   Yes Price: 35¢ | Volume: 0
#
# - KXNBAGAME-26FEB25SASTOR-SAS: San Antonio at Toronto Winner?
#   Event: KXNBAGAME-26FEB25SASTOR
#   Yes Price: 60¢ | Volume: 4
#   Yes Price: 68¢ | Volume: 4
#
# - KXNBAGAME-26FEB25OKCDET-OKC: Oklahoma City at Detroit Winner?
#   Event: KXNBAGAME-26FEB25OKCDET
#   Yes Price: 29¢ | Volume: 67
#   Yes Price: 37¢ | Volume: 67
#
# - KXNBAGAME-26FEB25OKCDET-DET: Oklahoma City at Detroit Winner?
#   Event: KXNBAGAME-26FEB25OKCDET
#   Yes Price: 59¢ | Volume: 61
#   Yes Price: 63¢ | Volume: 61
#
# - KXNBAGAME-26FEB25GSWMEM-MEM: Golden State at Memphis Winner?
#   Event: KXNBAGAME-26FEB25GSWMEM
#   Yes Price: 41¢ | Volume: 160
#   Yes Price: 45¢ | Volume: 160
#
# - KXNBAGAME-26FEB25GSWMEM-GSW: Golden State at Memphis Winner?
#   Event: KXNBAGAME-26FEB25GSWMEM
#   Yes Price: 43¢ | Volume: 125
#   Yes Price: 52¢ | Volume: 125
#
# - KXNBAGAME-26FEB24ORLLAL-ORL: Orlando at Los Angeles L Winner?
#   Event: KXNBAGAME-26FEB24ORLLAL
#   Yes Price: 31¢ | Volume: 8770
#   Yes Price: 33¢ | Volume: 8770
#
# - KXNBAGAME-26FEB24ORLLAL-LAL: Orlando at Los Angeles L Winner?
#   Event: KXNBAGAME-26FEB24ORLLAL
#   Yes Price: 67¢ | Volume: 7008
#   Yes Price: 69¢ | Volume: 7008
#
# - KXNBAGAME-26FEB24MINPOR-POR: Minnesota at Portland Winner?
#   Event: KXNBAGAME-26FEB24MINPOR
#   Yes Price: 34¢ | Volume: 2875
#   Yes Price: 35¢ | Volume: 2875
#
# - KXNBAGAME-26FEB24MINPOR-MIN: Minnesota at Portland Winner?
#   Event: KXNBAGAME-26FEB24MINPOR
#   Yes Price: 66¢ | Volume: 6732
#   Yes Price: 68¢ | Volume: 6732
#
# - KXNBAGAME-26FEB24MIAMIL-MIL: Miami at Milwaukee Winner?
#   Event: KXNBAGAME-26FEB24MIAMIL
#   Yes Price: 33¢ | Volume: 2115
#   Yes Price: 35¢ | Volume: 2115
#
# - KXNBAGAME-26FEB24MIAMIL-MIA: Miami at Milwaukee Winner?
#   Event: KXNBAGAME-26FEB24MIAMIL
#   Yes Price: 65¢ | Volume: 3173
#   Yes Price: 67¢ | Volume: 3173
#
# - KXNBAGAME-26FEB24CHACHI-CHI: Charlotte at Chicago Winner?
#   Event: KXNBAGAME-26FEB24CHACHI
#   Yes Price: 28¢ | Volume: 6715
#   Yes Price: 30¢ | Volume: 6715
#
# - KXNBAGAME-26FEB24CHACHI-CHA: Charlotte at Chicago Winner?
#   Event: KXNBAGAME-26FEB24CHACHI
#   Yes Price: 69¢ | Volume: 7940
#   Yes Price: 71¢ | Volume: 7940
#
# - KXNBAGAME-26FEB24BOSPHX-PHX: Boston at Phoenix Winner?
#   Event: KXNBAGAME-26FEB24BOSPHX
#   Yes Price: 28¢ | Volume: 6045
#   Yes Price: 30¢ | Volume: 6045
#
# - KXNBAGAME-26FEB24BOSPHX-BOS: Boston at Phoenix Winner?
#   Event: KXNBAGAME-26FEB24BOSPHX
#   Yes Price: 71¢ | Volume: 43443
#   Yes Price: 73¢ | Volume: 43443
#
# - KXNBAGAME-26FEB24GSWNOP-NOP: Golden State at New Orleans Winner?
#   Event: KXNBAGAME-26FEB24GSWNOP
#   Yes Price: 44¢ | Volume: 6971
#   Yes Price: 45¢ | Volume: 6971
#
# - KXNBAGAME-26FEB24GSWNOP-GSW: Golden State at New Orleans Winner?
#   Event: KXNBAGAME-26FEB24GSWNOP
#   Yes Price: 54¢ | Volume: 32496
#   Yes Price: 55¢ | Volume: 32496
#
# - KXNBAGAME-26FEB24NYKCLE-NYK: New York at Cleveland Winner?
#   Event: KXNBAGAME-26FEB24NYKCLE
#   Yes Price: 40¢ | Volume: 28441
#   Yes Price: 41¢ | Volume: 28441
#
# - KXNBAGAME-26FEB24NYKCLE-CLE: New York at Cleveland Winner?
#   Event: KXNBAGAME-26FEB24NYKCLE
#   Yes Price: 60¢ | Volume: 16957
#   Yes Price: 62¢ | Volume: 16957
#
# - KXNBAGAME-26FEB24DALBKN-DAL: Dallas at Brooklyn Winner?
#   Event: KXNBAGAME-26FEB24DALBKN
#   Yes Price: 56¢ | Volume: 12641
#   Yes Price: 58¢ | Volume: 12641
#
# - KXNBAGAME-26FEB24DALBKN-BKN: Dallas at Brooklyn Winner?
#   Event: KXNBAGAME-26FEB24DALBKN
#   Yes Price: 42¢ | Volume: 3100
#   Yes Price: 45¢ | Volume: 3100
#
# - KXNBAGAME-26FEB24OKCTOR-TOR: Oklahoma City at Toronto Winner?
#   Event: KXNBAGAME-26FEB24OKCTOR
#   Yes Price: 42¢ | Volume: 6866
#   Yes Price: 44¢ | Volume: 6866
#
# - KXNBAGAME-26FEB24OKCTOR-OKC: Oklahoma City at Toronto Winner?
#   Event: KXNBAGAME-26FEB24OKCTOR
#   Yes Price: 56¢ | Volume: 47856
#   Yes Price: 58¢ | Volume: 47856
#
# - KXNBAGAME-26FEB24WASATL-WAS: Washington at Atlanta Winner?
#   Event: KXNBAGAME-26FEB24WASATL
#   Yes Price: 18¢ | Volume: 9945
#   Yes Price: 19¢ | Volume: 9945
#
# - KXNBAGAME-26FEB24WASATL-ATL: Washington at Atlanta Winner?
#   Event: KXNBAGAME-26FEB24WASATL
#   Yes Price: 82¢ | Volume: 5853
#   Yes Price: 84¢ | Volume: 5853
#
# - KXNBAGAME-26FEB24PHIIND-PHI: Philadelphia at Indiana Winner?
#   Event: KXNBAGAME-26FEB24PHIIND
#   Yes Price: 71¢ | Volume: 30272
#   Yes Price: 73¢ | Volume: 30272
#
# - KXNBAGAME-26FEB24PHIIND-IND: Philadelphia at Indiana Winner?
#   Event: KXNBAGAME-26FEB24PHIIND
#   Yes Price: 27¢ | Volume: 4713
#   Yes Price: 29¢ | Volume: 4713
#
# - KXNBAGAME-26FEB23SACMEM-SAC: Sacramento at Memphis Winner?
#   Event: KXNBAGAME-26FEB23SACMEM
#   Yes Price: 41¢ | Volume: 125475
#   Yes Price: 43¢ | Volume: 125475
#
# - KXNBAGAME-26FEB23SACMEM-MEM: Sacramento at Memphis Winner?
#   Event: KXNBAGAME-26FEB23SACMEM
#   Yes Price: 57¢ | Volume: 296801
#   Yes Price: 59¢ | Volume: 296801
#
# - KXNBAGAME-26FEB23UTAHOU-UTA: Utah at Houston Winner?
#   Event: KXNBAGAME-26FEB23UTAHOU
#   Yes Price: 12¢ | Volume: 200050
#   Yes Price: 14¢ | Volume: 200050
#
# - KXNBAGAME-26FEB23UTAHOU-HOU: Utah at Houston Winner?
#   Event: KXNBAGAME-26FEB23UTAHOU
#   Yes Price: 86¢ | Volume: 209075
#   Yes Price: 87¢ | Volume: 209075
#
# - KXNBAGAME-26FEB23SASDET-SAS: San Antonio at Detroit Winner?
#   Event: KXNBAGAME-26FEB23SASDET
#   Yes Price: 48¢ | Volume: 467583
#   Yes Price: 49¢ | Volume: 467583
#
# - KXNBAGAME-26FEB23SASDET-DET: San Antonio at Detroit Winner?
#   Event: KXNBAGAME-26FEB23SASDET
#   Yes Price: 52¢ | Volume: 492401
#   Yes Price: 53¢ | Volume: 492401

# %%
# all of the markets 
markets_data[markets_data['markets']]
# Out:
# [{'can_close_early': True,
#   'close_time': '2026-03-12T03:00:00Z',
#   'created_time': '2026-02-23T17:02:05.873203Z',
#   'custom_strike': {'basketball_team': 'ba2cb6be-9827-46a8-8e6f-d8661307ba77'},
#   'early_close_condition': 'This market will close and expire after a winner is declared.',
#   'event_ticker': 'KXNBAGAME-26FEB25BOSDEN',
#   'expected_expiration_time': '2026-02-26T06:00:00Z',
#   'expiration_time': '2026-03-12T03:00:00Z',
#   'expiration_value': '',
#   'fractional_trading_enabled': False,
#   'last_price': 0,
#   'last_price_dollars': '0.0000',
#   'latest_expiration_time': '2026-03-12T03:00:00Z',
#   'liquidity': 0,
#   'liquidity_dollars': '0.0000',
#   'market_type': 'binary',
#   'no_ask': 49,
#   'no_ask_dollars': '0.4900',
#   'no_bid': 37,
#   'no_bid_dollars': '0.3700',
#   'no_sub_title': 'Denver',
#   'notional_value': 100,
#   'notional_value_dollars': '1.0000',
#   'open_interest': 0,
#   'open_interest_fp': '0.00',
#   'open_time': '2026-02-23T17:06:00Z',
#   'previous_price': 0,
#   'previous_price_dollars': '0.0000',
#   'previous_yes_ask': 0,
#   'previous_yes_ask_dollars': '0.0000',
#   'previous_yes_bid': 0,
#   'previous_yes_bid_dollars': '0.0000',
#   'price_level_structure': 'linear_cent',
#   'price_ranges': [{'end': '1.0000', 'start': '0.0000', 'step': '0.0100'}],
#   'response_price_units': 'usd_cent',
#   'result': '',
#   'rules_primary': 'If Denver wins the Boston at Denver professional basketball game originally scheduled for Feb 25, 2026, then the market resolves to Yes.',
#   'rules_secondary': '',
#   'settlement_timer_seconds': 30,
#   'status': 'active',
#   'strike_type': 'structured',
#   'subtitle': '',
#   'tick_size': 1,
#   'ticker': 'KXNBAGAME-26FEB25BOSDEN-DEN',
#   'title': 'Boston at Denver Winner?',
#   'updated_time': '2026-02-23T17:06:00.492087Z',
#   'volume': 0,
#   'volume_24h': 0,
#   'volume_24h_fp': '0.00',
#   'volume_fp': '0.00',
#   'yes_ask': 63,
#   'yes_ask_dollars': '0.6300',
#   'yes_bid': 51,
#   'yes_bid_dollars': '0.5100',
#   'yes_sub_title': 'Denver'},
#  {'can_close_early': True,
#   'close_time': '2026-03-12T03:00:00Z',
#   'created_time': '2026-02-23T17:02:05.873203Z',
#   'custom_strike': {'basketball_team': '6dd427f5-fa02-40ef-aa90-cfa73e0c539e'},
#   'early_close_condition': 'This market will close and expire after a winner is declared.',
#   'event_ticker': 'KXNBAGAME-26FEB25BOSDEN',
#   'expected_expiration_time': '2026-02-26T06:00:00Z',
#   'expiration_time': '2026-03-12T03:00:00Z',
#   'expiration_value': '',
#   'fractional_trading_enabled': False,
#   'last_price': 40,
#   'last_price_dollars': '0.4000',
#   'latest_expiration_time': '2026-03-12T03:00:00Z',
#   'liquidity': 0,
#   'liquidity_dollars': '0.0000',
#   'market_type': 'binary',
#   'no_ask': 63,
#   'no_ask_dollars': '0.6300',
#   'no_bid': 61,
#   'no_bid_dollars': '0.6100',
#   'no_sub_title': 'Boston',
#   'notional_value': 100,
#   'notional_value_dollars': '1.0000',
#   'open_interest': 11,
#   'open_interest_fp': '11.00',
#   'open_time': '2026-02-23T17:06:00Z',
#   'previous_price': 0,
#   'previous_price_dollars': '0.0000',
#   'previous_yes_ask': 0,
#   'previous_yes_ask_dollars': '0.0000',
#   'previous_yes_bid': 0,
#   'previous_yes_bid_dollars': '0.0000',
#   'price_level_structure': 'linear_cent',
#   'price_ranges': [{'end': '1.0000', 'start': '0.0000', 'step': '0.0100'}],
#   'response_price_units': 'usd_cent',
#   'result': '',
#   'rules_primary': 'If Boston wins the Boston at Denver professional basketball game originally scheduled for Feb 25, 2026, then the market resolves to Yes.',
#   'rules_secondary': '',
#   'settlement_timer_seconds': 30,
#   'status': 'active',
#   'strike_type': 'structured',
#   'subtitle': '',
#   'tick_size': 1,
#   'ticker': 'KXNBAGAME-26FEB25BOSDEN-BOS',
#   'title': 'Boston at Denver Winner?',
#   'updated_time': '2026-02-23T17:06:00.492087Z',
#   'volume': 11,
#   'volume_24h': 11,
#   'volume_24h_fp': '11.00',
#   'volume_fp': '11.00',
#   'yes_ask': 39,
#   'yes_ask_dollars': '0.3900',
#   'yes_bid': 37,
#   'yes_bid_dollars': '0.3700',
#   'yes_sub_title': 'Boston'},
#  {'can_close_early': True,
#   'close_time': '2026-03-12T01:00:00Z',
#   'created_time': '2026-02-23T17:02:05.806006Z',
#   'custom_strike': {'basketball_team': 'ab9e2e9a-3243-41b6-a291-95f4d9c6edf7'},
#   'early_close_condition': 'This market will close and expire after a winner is declared.',
#   'event_ticker': 'KXNBAGAME-26FEB25SACHOU',
#   'expected_expiration_time': '2026-02-26T04:00:00Z',
#   'expiration_time': '2026-03-12T01:00:00Z',
#   'expiration_value': '',
#   'fractional_trading_enabled': False,
#   'last_price': 0,
#   'last_price_dollars': '0.0000',
#   'latest_expiration_time': '2026-03-12T01:00:00Z',
#   'liquidity': 0,
#   'liquidity_dollars': '0.0000',
#   'market_type': 'binary',
#   'no_ask': 86,
#   'no_ask_dollars': '0.8600',
#   'no_bid': 82,
#   'no_bid_dollars': '0.8200',
#   'no_sub_title': 'Sacramento',
#   'notional_value': 100,
#   'notional_value_dollars': '1.0000',
#   'open_interest': 0,
#   'open_interest_fp': '0.00',
#   'open_time': '2026-02-23T17:06:00Z',
#   'previous_price': 0,
#   'previous_price_dollars': '0.0000',
#   'previous_yes_ask': 0,
#   'previous_yes_ask_dollars': '0.0000',
#   'previous_yes_bid': 0,
#   'previous_yes_bid_dollars': '0.0000',
#   'price_level_structure': 'linear_cent',
#   'price_ranges': [{'end': '1.0000', 'start': '0.0000', 'step': '0.0100'}],
#   'response_price_units': 'usd_cent',
#   'result': '',
#   'rules_primary': 'If Sacramento wins the Sacramento at Houston professional basketball game originally scheduled for Feb 25, 2026, then the market resolves to Yes.',
#   'rules_secondary': '',
#   'settlement_timer_seconds': 30,
#   'status': 'active',
#   'strike_type': 'structured',
#   'subtitle': '',
#   'tick_size': 1,
#   'ticker': 'KXNBAGAME-26FEB25SACHOU-SAC',
#   'title': 'Sacramento at Houston Winner?',
#   'updated_time': '2026-02-23T17:06:00.492087Z',
#   'volume': 0,
#   'volume_24h': 0,
#   'volume_24h_fp': '0.00',
#   'volume_fp': '0.00',
#   'yes_ask': 18,
#   'yes_ask_dollars': '0.1800',
#   'yes_bid': 14,
#   'yes_bid_dollars': '0.1400',
#   'yes_sub_title': 'Sacramento'},
#  {'can_close_early': True,
#   'close_time': '2026-03-12T01:00:00Z',
#   'created_time': '2026-02-23T17:02:05.806006Z',
#   'custom_strike': {'basketball_team': 'a8625e4b-4ae6-4062-a7c1-0b6e1f4ae211'},
#   'early_close_condition': 'This market will close and expire after a winner is declared.',
#   'event_ticker': 'KXNBAGAME-26FEB25SACHOU',
#   'expected_expiration_time': '2026-02-26T04:00:00Z',
#   'expiration_time': '2026-03-12T01:00:00Z',
#   'expiration_value': '',
#   'fractional_trading_enabled': False,
#   'last_price': 76,
#   'last_price_dollars': '0.7600',
#   'latest_expiration_time': '2026-03-12T01:00:00Z',
#   'liquidity': 0,
#   'liquidity_dollars': '0.0000',
#   'market_type': 'binary',
#   'no_ask': 23,
#   'no_ask_dollars': '0.2300',
#   'no_bid': 19,
#   'no_bid_dollars': '0.1900',
#   'no_sub_title': 'Houston',
#   'notional_value': 100,
#   'notional_value_dollars': '1.0000',
#   'open_interest': 20,
#   'open_interest_fp': '20.00',
#   'open_time': '2026-02-23T17:06:00Z',
#   'previous_price': 0,
#   'previous_price_dollars': '0.0000',
#   'previous_yes_ask': 0,
#   'previous_yes_ask_dollars': '0.0000',
#   'previous_yes_bid': 0,
#   'previous_yes_bid_dollars': '0.0000',
#   'price_level_structure': 'linear_cent',
#   'price_ranges': [{'end': '1.0000', 'start': '0.0000', 'step': '0.0100'}],
#   'response_price_units': 'usd_cent',
#   'result': '',
#   'rules_primary': 'If Houston wins the Sacramento at Houston professional basketball game originally scheduled for Feb 25, 2026, then the market resolves to Yes.',
#   'rules_secondary': '',
#   'settlement_timer_seconds': 30,
#   'status': 'active',
#   'strike_type': 'structured',
#   'subtitle': '',
#   'tick_size': 1,
#   'ticker': 'KXNBAGAME-26FEB25SACHOU-HOU',
#   'title': 'Sacramento at Houston Winner?',
#   'updated_time': '2026-02-23T17:06:00.492087Z',
#   'volume': 20,
#   'volume_24h': 20,
#   'volume_24h_fp': '20.00',
#   'volume_fp': '20.00',
#   'yes_ask': 81,
#   'yes_ask_dollars': '0.8100',
#   'yes_bid': 77,
#   'yes_bid_dollars': '0.7700',
#   'yes_sub_title': 'Houston'},
#  {'can_close_early': True,
#   'close_time': '2026-03-12T01:00:00Z',
#   'created_time': '2026-02-23T17:02:04.993744Z',
#   'custom_strike': {'basketball_team': '5dc3fe01-79a4-4f2f-a953-d922ea4a6dd3'},
#   'early_close_condition': 'This market will close and expire after a winner is declared.',
#   'event_ticker': 'KXNBAGAME-26FEB25CLEMIL',
#   'expected_expiration_time': '2026-02-26T04:00:00Z',
#   'expiration_time': '2026-03-12T01:00:00Z',
#   'expiration_value': '',
#   'fractional_trading_enabled': False,
#   'last_price': 33,
#   'last_price_dollars': '0.3300',
#   'latest_expiration_time': '2026-03-12T01:00:00Z',
#   'liquidity': 0,
#   'liquidity_dollars': '0.0000',
#   'market_type': 'binary',
#   'no_ask': 78,
#   'no_ask_dollars': '0.7800',
#   'no_bid': 68,
#   'no_bid_dollars': '0.6800',
#   'no_sub_title': 'Milwaukee',
#   'notional_value': 100,
#   'notional_value_dollars': '1.0000',
#   'open_interest': 3,
#   'open_interest_fp': '3.00',
#   'open_time': '2026-02-23T17:06:00Z',
#   'previous_price': 0,
#   'previous_price_dollars': '0.0000',
#   'previous_yes_ask': 0,
#   'previous_yes_ask_dollars': '0.0000',
#   'previous_yes_bid': 0,
#   'previous_yes_bid_dollars': '0.0000',
#   'price_level_structure': 'linear_cent',
#   'price_ranges': [{'end': '1.0000', 'start': '0.0000', 'step': '0.0100'}],
#   'response_price_units': 'usd_cent',
#   'result': '',
#   'rules_primary': 'If Milwaukee wins the Cleveland at Milwaukee professional basketball game originally scheduled for Feb 25, 2026, then the market resolves to Yes.',
#   'rules_secondary': '',
#   'settlement_timer_seconds': 30,
#   'status': 'active',
#   'strike_type': 'structured',
#   'subtitle': '',
#   'tick_size': 1,
#   'ticker': 'KXNBAGAME-26FEB25CLEMIL-MIL',
#   'title': 'Cleveland at Milwaukee Winner?',
#   'updated_time': '2026-02-23T17:06:00.492087Z',
#   'volume': 3,
#   'volume_24h': 3,
#   'volume_24h_fp': '3.00',
#   'volume_fp': '3.00',
#   'yes_ask': 32,
#   'yes_ask_dollars': '0.3200',
#   'yes_bid': 22,
#   'yes_bid_dollars': '0.2200',
#   'yes_sub_title': 'Milwaukee'},
#  {'can_close_early': True,
#   'close_time': '2026-03-12T01:00:00Z',
#   'created_time': '2026-02-23T17:02:04.993744Z',
#   'custom_strike': {'basketball_team': '90381a35-42a6-4975-851f-175418e4271a'},
#   'early_close_condition': 'This market will close and expire after a winner is declared.',
#   'event_ticker': 'KXNBAGAME-26FEB25CLEMIL',
#   'expected_expiration_time': '2026-02-26T04:00:00Z',
#   'expiration_time': '2026-03-12T01:00:00Z',
#   'expiration_value': '',
#   'fractional_trading_enabled': False,
#   'last_price': 71,
#   'last_price_dollars': '0.7100',
#   'latest_expiration_time': '2026-03-12T01:00:00Z',
#   'liquidity': 0,
#   'liquidity_dollars': '0.0000',
#   'market_type': 'binary',
#   'no_ask': 33,
#   'no_ask_dollars': '0.3300',
#   'no_bid': 29,
#   'no_bid_dollars': '0.2900',
#   'no_sub_title': 'Cleveland',
#   'notional_value': 100,
#   'notional_value_dollars': '1.0000',
#   'open_interest': 55,
#   'open_interest_fp': '55.00',
#   'open_time': '2026-02-23T17:06:00Z',
#   'previous_price': 0,
#   'previous_price_dollars': '0.0000',
#   'previous_yes_ask': 0,
#   'previous_yes_ask_dollars': '0.0000',
#   'previous_yes_bid': 0,
#   'previous_yes_bid_dollars': '0.0000',
#   'price_level_structure': 'linear_cent',
#   'price_ranges': [{'end': '1.0000', 'start': '0.0000', 'step': '0.0100'}],
#   'response_price_units': 'usd_cent',
#   'result': '',
#   'rules_primary': 'If Cleveland wins the Cleveland at Milwaukee professional basketball game originally scheduled for Feb 25, 2026, then the market resolves to Yes.',
#   'rules_secondary': '',
#   'settlement_timer_seconds': 30,
#   'status': 'active',
#   'strike_type': 'structured',
#   'subtitle': '',
#   'tick_size': 1,
#   'ticker': 'KXNBAGAME-26FEB25CLEMIL-CLE',
#   'title': 'Cleveland at Milwaukee Winner?',
#   'updated_time': '2026-02-23T17:06:00.492087Z',
#   'volume': 59,
#   'volume_24h': 59,
#   'volume_24h_fp': '59.00',
#   'volume_fp': '59.00',
#   'yes_ask': 71,
#   'yes_ask_dollars': '0.7100',
#   'yes_bid': 67,
#   'yes_bid_dollars': '0.6700',
#   'yes_sub_title': 'Cleveland'},
#  {'can_close_early': True,
#   'close_time': '2026-03-12T00:30:00Z',
#   'created_time': '2026-02-23T17:02:04.52877Z',
#   'custom_strike': {'basketball_team': '96c447dd-2cdd-4c58-a151-ef0df87de981'},
#   'early_close_condition': 'This market will close and expire after a winner is declared.',
#   'event_ticker': 'KXNBAGAME-26FEB25SASTOR',
#   'expected_expiration_time': '2026-02-26T03:30:00Z',
#   'expiration_time': '2026-03-12T00:30:00Z',
#   'expiration_value': '',
#   'fractional_trading_enabled': False,
#   'last_price': 0,
#   'last_price_dollars': '0.0000',
#   'latest_expiration_time': '2026-03-12T00:30:00Z',
#   'liquidity': 0,
#   'liquidity_dollars': '0.0000',
#   'market_type': 'binary',
#   'no_ask': 69,
#   'no_ask_dollars': '0.6900',
#   'no_bid': 65,
#   'no_bid_dollars': '0.6500',
#   'no_sub_title': 'Toronto',
#   'notional_value': 100,
#   'notional_value_dollars': '1.0000',
#   'open_interest': 0,
#   'open_interest_fp': '0.00',
#   'open_time': '2026-02-23T17:06:00Z',
#   'previous_price': 0,
#   'previous_price_dollars': '0.0000',
#   'previous_yes_ask': 0,
#   'previous_yes_ask_dollars': '0.0000',
#   'previous_yes_bid': 0,
#   'previous_yes_bid_dollars': '0.0000',
#   'price_level_structure': 'linear_cent',
#   'price_ranges': [{'end': '1.0000', 'start': '0.0000', 'step': '0.0100'}],
#   'response_price_units': 'usd_cent',
#   'result': '',
#   'rules_primary': 'If Toronto wins the San Antonio at Toronto professional basketball game originally scheduled for Feb 25, 2026, then the market resolves to Yes.',
#   'rules_secondary': '',
#   'settlement_timer_seconds': 30,
#   'status': 'active',
#   'strike_type': 'structured',
#   'subtitle': '',
#   'tick_size': 1,
#   'ticker': 'KXNBAGAME-26FEB25SASTOR-TOR',
#   'title': 'San Antonio at Toronto Winner?',
#   'updated_time': '2026-02-23T17:06:00.492087Z',
#   'volume': 0,
#   'volume_24h': 0,
#   'volume_24h_fp': '0.00',
#   'volume_fp': '0.00',
#   'yes_ask': 35,
#   'yes_ask_dollars': '0.3500',
#   'yes_bid': 31,
#   'yes_bid_dollars': '0.3100',
#   'yes_sub_title': 'Toronto'},
#  {'can_close_early': True,
#   'close_time': '2026-03-12T00:30:00Z',
#   'created_time': '2026-02-23T17:02:04.52877Z',
#   'custom_strike': {'basketball_team': 'ad36c3e8-4194-4e63-920f-7c50f46191a6'},
#   'early_close_condition': 'This market will close and expire after a winner is declared.',
#   'event_ticker': 'KXNBAGAME-26FEB25SASTOR',
#   'expected_expiration_time': '2026-02-26T03:30:00Z',
#   'expiration_time': '2026-03-12T00:30:00Z',
#   'expiration_value': '',
#   'fractional_trading_enabled': False,
#   'last_price': 69,
#   'last_price_dollars': '0.6900',
#   'latest_expiration_time': '2026-03-12T00:30:00Z',
#   'liquidity': 0,
#   'liquidity_dollars': '0.0000',
#   'market_type': 'binary',
#   'no_ask': 40,
#   'no_ask_dollars': '0.4000',
#   'no_bid': 32,
#   'no_bid_dollars': '0.3200',
#   'no_sub_title': 'San Antonio',
#   'notional_value': 100,
#   'notional_value_dollars': '1.0000',
#   'open_interest': 4,
#   'open_interest_fp': '4.00',
#   'open_time': '2026-02-23T17:06:00Z',
#   'previous_price': 0,
#   'previous_price_dollars': '0.0000',
#   'previous_yes_ask': 0,
#   'previous_yes_ask_dollars': '0.0000',
#   'previous_yes_bid': 0,
#   'previous_yes_bid_dollars': '0.0000',
#   'price_level_structure': 'linear_cent',
#   'price_ranges': [{'end': '1.0000', 'start': '0.0000', 'step': '0.0100'}],
#   'response_price_units': 'usd_cent',
#   'result': '',
#   'rules_primary': 'If San Antonio wins the San Antonio at Toronto professional basketball game originally scheduled for Feb 25, 2026, then the market resolves to Yes.',
#   'rules_secondary': '',
#   'settlement_timer_seconds': 30,
#   'status': 'active',
#   'strike_type': 'structured',
#   'subtitle': '',
#   'tick_size': 1,
#   'ticker': 'KXNBAGAME-26FEB25SASTOR-SAS',
#   'title': 'San Antonio at Toronto Winner?',
#   'updated_time': '2026-02-23T17:06:00.492087Z',
#   'volume': 4,
#   'volume_24h': 4,
#   'volume_24h_fp': '4.00',
#   'volume_fp': '4.00',
#   'yes_ask': 68,
#   'yes_ask_dollars': '0.6800',
#   'yes_bid': 60,
#   'yes_bid_dollars': '0.6000',
#   'yes_sub_title': 'San Antonio'},
#  {'can_close_early': True,
#   'close_time': '2026-03-12T00:30:00Z',
#   'created_time': '2026-02-23T17:02:04.493986Z',
#   'custom_strike': {'basketball_team': 'a85f6eca-2f3b-4f61-83ab-8d049f59ce2c'},
#   'early_close_condition': 'This market will close and expire after a winner is declared.',
#   'event_ticker': 'KXNBAGAME-26FEB25OKCDET',
#   'expected_expiration_time': '2026-02-26T03:30:00Z',
#   'expiration_time': '2026-03-12T00:30:00Z',
#   'expiration_value': '',
#   'fractional_trading_enabled': False,
#   'last_price': 38,
#   'last_price_dollars': '0.3800',
#   'latest_expiration_time': '2026-03-12T00:30:00Z',
#   'liquidity': 0,
#   'liquidity_dollars': '0.0000',
#   'market_type': 'binary',
#   'no_ask': 71,
#   'no_ask_dollars': '0.7100',
#   'no_bid': 63,
#   'no_bid_dollars': '0.6300',
#   'no_sub_title': 'Oklahoma City',
#   'notional_value': 100,
#   'notional_value_dollars': '1.0000',
#   'open_interest': 67,
#   'open_interest_fp': '67.00',
#   'open_time': '2026-02-23T17:06:00Z',
#   'previous_price': 0,
#   'previous_price_dollars': '0.0000',
#   'previous_yes_ask': 0,
#   'previous_yes_ask_dollars': '0.0000',
#   'previous_yes_bid': 0,
#   'previous_yes_bid_dollars': '0.0000',
#   'price_level_structure': 'linear_cent',
#   'price_ranges': [{'end': '1.0000', 'start': '0.0000', 'step': '0.0100'}],
#   'response_price_units': 'usd_cent',
#   'result': '',
#   'rules_primary': 'If Oklahoma City wins the Oklahoma City at Detroit professional basketball game originally scheduled for Feb 25, 2026, then the market resolves to Yes.',
#   'rules_secondary': '',
#   'settlement_timer_seconds': 30,
#   'status': 'active',
#   'strike_type': 'structured',
#   'subtitle': '',
#   'tick_size': 1,
#   'ticker': 'KXNBAGAME-26FEB25OKCDET-OKC',
#   'title': 'Oklahoma City at Detroit Winner?',
#   'updated_time': '2026-02-23T17:06:00.492087Z',
#   'volume': 67,
#   'volume_24h': 57,
#   'volume_24h_fp': '57.00',
#   'volume_fp': '67.00',
#   'yes_ask': 37,
#   'yes_ask_dollars': '0.3700',
#   'yes_bid': 29,
#   'yes_bid_dollars': '0.2900',
#   'yes_sub_title': 'Oklahoma City'},
#  {'can_close_early': True,
#   'close_time': '2026-03-12T00:30:00Z',
#   'created_time': '2026-02-23T17:02:04.493986Z',
#   'custom_strike': {'basketball_team': '65569528-1888-40aa-9d62-2b0e8142a9b4'},
#   'early_close_condition': 'This market will close and expire after a winner is declared.',
#   'event_ticker': 'KXNBAGAME-26FEB25OKCDET',
#   'expected_expiration_time': '2026-02-26T03:30:00Z',
#   'expiration_time': '2026-03-12T00:30:00Z',
#   'expiration_value': '',
#   'fractional_trading_enabled': False,
#   'last_price': 64,
#   'last_price_dollars': '0.6400',
#   'latest_expiration_time': '2026-03-12T00:30:00Z',
#   'liquidity': 0,
#   'liquidity_dollars': '0.0000',
#   'market_type': 'binary',
#   'no_ask': 41,
#   'no_ask_dollars': '0.4100',
#   'no_bid': 37,
#   'no_bid_dollars': '0.3700',
#   'no_sub_title': 'Detroit',
#   'notional_value': 100,
#   'notional_value_dollars': '1.0000',
#   'open_interest': 61,
#   'open_interest_fp': '61.00',
#   'open_time': '2026-02-23T17:06:00Z',
#   'previous_price': 0,
#   'previous_price_dollars': '0.0000',
#   'previous_yes_ask': 0,
#   'previous_yes_ask_dollars': '0.0000',
#   'previous_yes_bid': 0,
#   'previous_yes_bid_dollars': '0.0000',
#   'price_level_structure': 'linear_cent',
#   'price_ranges': [{'end': '1.0000', 'start': '0.0000', 'step': '0.0100'}],
#   'response_price_units': 'usd_cent',
#   'result': '',
#   'rules_primary': 'If Detroit wins the Oklahoma City at Detroit professional basketball game originally scheduled for Feb 25, 2026, then the market resolves to Yes.',
#   'rules_secondary': '',
#   'settlement_timer_seconds': 30,
#   'status': 'active',
#   'strike_type': 'structured',
#   'subtitle': '',
#   'tick_size': 1,
#   'ticker': 'KXNBAGAME-26FEB25OKCDET-DET',
#   'title': 'Oklahoma City at Detroit Winner?',
#   'updated_time': '2026-02-23T17:06:00.492087Z',
#   'volume': 61,
#   'volume_24h': 61,
#   'volume_24h_fp': '61.00',
#   'volume_fp': '61.00',
#   'yes_ask': 63,
#   'yes_ask_dollars': '0.6300',
#   'yes_bid': 59,
#   'yes_bid_dollars': '0.5900',
#   'yes_sub_title': 'Detroit'},
#  {'can_close_early': True,
#   'close_time': '2026-03-12T00:30:00Z',
#   'created_time': '2026-02-23T17:02:04.116087Z',
#   'custom_strike': {'basketball_team': '1cfe70b8-4dfc-47dc-acca-b68d4a725972'},
#   'early_close_condition': 'This market will close and expire after a winner is declared.',
#   'event_ticker': 'KXNBAGAME-26FEB25GSWMEM',
#   'expected_expiration_time': '2026-02-26T03:30:00Z',
#   'expiration_time': '2026-03-12T00:30:00Z',
#   'expiration_value': '',
#   'fractional_trading_enabled': False,
#   'last_price': 44,
#   'last_price_dollars': '0.4400',
#   'latest_expiration_time': '2026-03-12T00:30:00Z',
#   'liquidity': 0,
#   'liquidity_dollars': '0.0000',
#   'market_type': 'binary',
#   'no_ask': 59,
#   'no_ask_dollars': '0.5900',
#   'no_bid': 55,
#   'no_bid_dollars': '0.5500',
#   'no_sub_title': 'Memphis',
#   'notional_value': 100,
#   'notional_value_dollars': '1.0000',
#   'open_interest': 160,
#   'open_interest_fp': '160.00',
#   'open_time': '2026-02-23T17:06:00Z',
#   'previous_price': 0,
#   'previous_price_dollars': '0.0000',
#   'previous_yes_ask': 0,
#   'previous_yes_ask_dollars': '0.0000',
#   'previous_yes_bid': 0,
#   'previous_yes_bid_dollars': '0.0000',
#   'price_level_structure': 'linear_cent',
#   'price_ranges': [{'end': '1.0000', 'start': '0.0000', 'step': '0.0100'}],
#   'response_price_units': 'usd_cent',
#   'result': '',
#   'rules_primary': 'If Memphis wins the Golden State at Memphis professional basketball game originally scheduled for Feb 25, 2026, then the market resolves to Yes.',
#   'rules_secondary': '',
#   'settlement_timer_seconds': 30,
#   'status': 'active',
#   'strike_type': 'structured',
#   'subtitle': '',
#   'tick_size': 1,
#   'ticker': 'KXNBAGAME-26FEB25GSWMEM-MEM',
#   'title': 'Golden State at Memphis Winner?',
#   'updated_time': '2026-02-23T17:06:00.492087Z',
#   'volume': 160,
#   'volume_24h': 83,
#   'volume_24h_fp': '83.00',
#   'volume_fp': '160.00',
#   'yes_ask': 45,
#   'yes_ask_dollars': '0.4500',
#   'yes_bid': 41,
#   'yes_bid_dollars': '0.4100',
#   'yes_sub_title': 'Memphis'},
#  {'can_close_early': True,
#   'close_time': '2026-03-12T00:30:00Z',
#   'created_time': '2026-02-23T17:02:04.116087Z',
#   'custom_strike': {'basketball_team': '502c629b-4da7-40fd-92ab-20cb55411c35'},
#   'early_close_condition': 'This market will close and expire after a winner is declared.',
#   'event_ticker': 'KXNBAGAME-26FEB25GSWMEM',
#   'expected_expiration_time': '2026-02-26T03:30:00Z',
#   'expiration_time': '2026-03-12T00:30:00Z',
#   'expiration_value': '',
#   'fractional_trading_enabled': False,
#   'last_price': 52,
#   'last_price_dollars': '0.5200',
#   'latest_expiration_time': '2026-03-12T00:30:00Z',
#   'liquidity': 0,
#   'liquidity_dollars': '0.0000',
#   'market_type': 'binary',
#   'no_ask': 57,
#   'no_ask_dollars': '0.5700',
#   'no_bid': 48,
#   'no_bid_dollars': '0.4800',
#   'no_sub_title': 'Golden State',
#   'notional_value': 100,
#   'notional_value_dollars': '1.0000',
#   'open_interest': 125,
#   'open_interest_fp': '125.00',
#   'open_time': '2026-02-23T17:06:00Z',
#   'previous_price': 0,
#   'previous_price_dollars': '0.0000',
#   'previous_yes_ask': 0,
#   'previous_yes_ask_dollars': '0.0000',
#   'previous_yes_bid': 0,
#   'previous_yes_bid_dollars': '0.0000',
#   'price_level_structure': 'linear_cent',
#   'price_ranges': [{'end': '1.0000', 'start': '0.0000', 'step': '0.0100'}],
#   'response_price_units': 'usd_cent',
#   'result': '',
#   'rules_primary': 'If Golden State wins the Golden State at Memphis professional basketball game originally scheduled for Feb 25, 2026, then the market resolves to Yes.',
#   'rules_secondary': '',
#   'settlement_timer_seconds': 30,
#   'status': 'active',
#   'strike_type': 'structured',
#   'subtitle': '',
#   'tick_size': 1,
#   'ticker': 'KXNBAGAME-26FEB25GSWMEM-GSW',
#   'title': 'Golden State at Memphis Winner?',
#   'updated_time': '2026-02-23T17:06:00.492087Z',
#   'volume': 125,
#   'volume_24h': 13,
#   'volume_24h_fp': '13.00',
#   'volume_fp': '125.00',
#   'yes_ask': 52,
#   'yes_ask_dollars': '0.5200',
#   'yes_bid': 43,
#   'yes_bid_dollars': '0.4300',
#   'yes_sub_title': 'Golden State'},
#  {'can_close_early': True,
#   'close_time': '2026-03-11T03:30:00Z',
#   'created_time': '2026-02-22T20:02:34.519657Z',
#   'custom_strike': {'basketball_team': '00c3e69d-d9b9-4ac3-bf79-19707fe43637'},
#   'early_close_condition': 'This market will close and expire after a winner is declared.',
#   'event_ticker': 'KXNBAGAME-26FEB24ORLLAL',
#   'expected_expiration_time': '2026-02-25T06:30:00Z',
#   'expiration_time': '2026-03-11T03:30:00Z',
#   'expiration_value': '',
#   'fractional_trading_enabled': False,
#   'last_price': 33,
#   'last_price_dollars': '0.3300',
#   'latest_expiration_time': '2026-03-11T03:30:00Z',
#   'liquidity': 0,
#   'liquidity_dollars': '0.0000',
#   'market_type': 'binary',
#   'no_ask': 69,
#   'no_ask_dollars': '0.6900',
#   'no_bid': 67,
#   'no_bid_dollars': '0.6700',
#   'no_sub_title': 'Orlando',
#   'notional_value': 100,
#   'notional_value_dollars': '1.0000',
#   'open_interest': 7553,
#   'open_interest_fp': '7553.00',
#   'open_time': '2026-02-22T20:06:00Z',
#   'previous_price': 0,
#   'previous_price_dollars': '0.0000',
#   'previous_yes_ask': 0,
#   'previous_yes_ask_dollars': '0.0000',
#   'previous_yes_bid': 0,
#   'previous_yes_bid_dollars': '0.0000',
#   'price_level_structure': 'linear_cent',
#   'price_ranges': [{'end': '1.0000', 'start': '0.0000', 'step': '0.0100'}],
#   'response_price_units': 'usd_cent',
#   'result': '',
#   'rules_primary': 'If Orlando wins the Orlando at Los Angeles L professional basketball game originally scheduled for Feb 24, 2026, then the market resolves to Yes.',
#   'rules_secondary': '',
#   'settlement_timer_seconds': 30,
#   'status': 'active',
#   'strike_type': 'structured',
#   'subtitle': '',
#   'tick_size': 1,
#   'ticker': 'KXNBAGAME-26FEB24ORLLAL-ORL',
#   'title': 'Orlando at Los Angeles L Winner?',
#   'updated_time': '2026-02-22T20:06:00.492842Z',
#   'volume': 8770,
#   'volume_24h': 8738,
#   'volume_24h_fp': '8738.00',
#   'volume_fp': '8770.00',
#   'yes_ask': 33,
#   'yes_ask_dollars': '0.3300',
#   'yes_bid': 31,
#   'yes_bid_dollars': '0.3100',
#   'yes_sub_title': 'Orlando'},
#  {'can_close_early': True,
#   'close_time': '2026-03-11T03:30:00Z',
#   'created_time': '2026-02-22T20:02:34.519657Z',
#   'custom_strike': {'basketball_team': '2ef4d31c-0b46-4f43-a403-f44d62489034'},
#   'early_close_condition': 'This market will close and expire after a winner is declared.',
#   'event_ticker': 'KXNBAGAME-26FEB24ORLLAL',
#   'expected_expiration_time': '2026-02-25T06:30:00Z',
#   'expiration_time': '2026-03-11T03:30:00Z',
#   'expiration_value': '',
#   'fractional_trading_enabled': False,
#   'last_price': 69,
#   'last_price_dollars': '0.6900',
#   'latest_expiration_time': '2026-03-11T03:30:00Z',
#   'liquidity': 0,
#   'liquidity_dollars': '0.0000',
#   'market_type': 'binary',
#   'no_ask': 33,
#   'no_ask_dollars': '0.3300',
#   'no_bid': 31,
#   'no_bid_dollars': '0.3100',
#   'no_sub_title': 'Los Angeles L',
#   'notional_value': 100,
#   'notional_value_dollars': '1.0000',
#   'open_interest': 6594,
#   'open_interest_fp': '6594.00',
#   'open_time': '2026-02-22T20:06:00Z',
#   'previous_price': 0,
#   'previous_price_dollars': '0.0000',
#   'previous_yes_ask': 0,
#   'previous_yes_ask_dollars': '0.0000',
#   'previous_yes_bid': 0,
#   'previous_yes_bid_dollars': '0.0000',
#   'price_level_structure': 'linear_cent',
#   'price_ranges': [{'end': '1.0000', 'start': '0.0000', 'step': '0.0100'}],
#   'response_price_units': 'usd_cent',
#   'result': '',
#   'rules_primary': 'If Los Angeles L wins the Orlando at Los Angeles L professional basketball game originally scheduled for Feb 24, 2026, then the market resolves to Yes.',
#   'rules_secondary': '',
#   'settlement_timer_seconds': 30,
#   'status': 'active',
#   'strike_type': 'structured',
#   'subtitle': '',
#   'tick_size': 1,
#   'ticker': 'KXNBAGAME-26FEB24ORLLAL-LAL',
#   'title': 'Orlando at Los Angeles L Winner?',
#   'updated_time': '2026-02-22T20:06:00.492842Z',
#   'volume': 7008,
#   'volume_24h': 6984,
#   'volume_24h_fp': '6984.00',
#   'volume_fp': '7008.00',
#   'yes_ask': 69,
#   'yes_ask_dollars': '0.6900',
#   'yes_bid': 67,
#   'yes_bid_dollars': '0.6700',
#   'yes_sub_title': 'Los Angeles L'},
#  {'can_close_early': True,
#   'close_time': '2026-03-11T03:00:00Z',
#   'created_time': '2026-02-22T17:02:49.631065Z',
#   'custom_strike': {'basketball_team': '2229b01e-68eb-46ad-adf4-71a9533c84fc'},
#   'early_close_condition': 'This market will close and expire after a winner is declared.',
#   'event_ticker': 'KXNBAGAME-26FEB24MINPOR',
#   'expected_expiration_time': '2026-02-25T06:00:00Z',
#   'expiration_time': '2026-03-11T03:00:00Z',
#   'expiration_value': '',
#   'fractional_trading_enabled': False,
#   'last_price': 35,
#   'last_price_dollars': '0.3500',
#   'latest_expiration_time': '2026-03-11T03:00:00Z',
#   'liquidity': 0,
#   'liquidity_dollars': '0.0000',
#   'market_type': 'binary',
#   'no_ask': 66,
#   'no_ask_dollars': '0.6600',
#   'no_bid': 65,
#   'no_bid_dollars': '0.6500',
#   'no_sub_title': 'Portland',
#   'notional_value': 100,
#   'notional_value_dollars': '1.0000',
#   'open_interest': 2532,
#   'open_interest_fp': '2532.00',
#   'open_time': '2026-02-22T17:06:00Z',
#   'previous_price': 0,
#   'previous_price_dollars': '0.0000',
#   'previous_yes_ask': 42,
#   'previous_yes_ask_dollars': '0.4200',
#   'previous_yes_bid': 30,
#   'previous_yes_bid_dollars': '0.3000',
#   'price_level_structure': 'linear_cent',
#   'price_ranges': [{'end': '1.0000', 'start': '0.0000', 'step': '0.0100'}],
#   'response_price_units': 'usd_cent',
#   'result': '',
#   'rules_primary': 'If Portland wins the Minnesota at Portland professional basketball game originally scheduled for Feb 24, 2026, then the market resolves to Yes.',
#   'rules_secondary': '',
#   'settlement_timer_seconds': 30,
#   'status': 'active',
#   'strike_type': 'structured',
#   'subtitle': '',
#   'tick_size': 1,
#   'ticker': 'KXNBAGAME-26FEB24MINPOR-POR',
#   'title': 'Minnesota at Portland Winner?',
#   'updated_time': '2026-02-22T17:06:00.49251Z',
#   'volume': 2875,
#   'volume_24h': 2864,
#   'volume_24h_fp': '2864.00',
#   'volume_fp': '2875.00',
#   'yes_ask': 35,
#   'yes_ask_dollars': '0.3500',
#   'yes_bid': 34,
#   'yes_bid_dollars': '0.3400',
#   'yes_sub_title': 'Portland'},
#  {'can_close_early': True,
#   'close_time': '2026-03-11T03:00:00Z',
#   'created_time': '2026-02-22T17:02:49.631065Z',
#   'custom_strike': {'basketball_team': '29e3c04e-fadb-4006-be20-cbb8c159ce0e'},
#   'early_close_condition': 'This market will close and expire after a winner is declared.',
#   'event_ticker': 'KXNBAGAME-26FEB24MINPOR',
#   'expected_expiration_time': '2026-02-25T06:00:00Z',
#   'expiration_time': '2026-03-11T03:00:00Z',
#   'expiration_value': '',
#   'fractional_trading_enabled': False,
#   'last_price': 68,
#   'last_price_dollars': '0.6800',
#   'latest_expiration_time': '2026-03-11T03:00:00Z',
#   'liquidity': 0,
#   'liquidity_dollars': '0.0000',
#   'market_type': 'binary',
#   'no_ask': 34,
#   'no_ask_dollars': '0.3400',
#   'no_bid': 32,
#   'no_bid_dollars': '0.3200',
#   'no_sub_title': 'Minnesota',
#   'notional_value': 100,
#   'notional_value_dollars': '1.0000',
#   'open_interest': 6179,
#   'open_interest_fp': '6179.00',
#   'open_time': '2026-02-22T17:06:00Z',
#   'previous_price': 71,
#   'previous_price_dollars': '0.7100',
#   'previous_yes_ask': 63,
#   'previous_yes_ask_dollars': '0.6300',
#   'previous_yes_bid': 62,
#   'previous_yes_bid_dollars': '0.6200',
#   'price_level_structure': 'linear_cent',
#   'price_ranges': [{'end': '1.0000', 'start': '0.0000', 'step': '0.0100'}],
#   'response_price_units': 'usd_cent',
#   'result': '',
#   'rules_primary': 'If Minnesota wins the Minnesota at Portland professional basketball game originally scheduled for Feb 24, 2026, then the market resolves to Yes.',
#   'rules_secondary': '',
#   'settlement_timer_seconds': 30,
#   'status': 'active',
#   'strike_type': 'structured',
#   'subtitle': '',
#   'tick_size': 1,
#   'ticker': 'KXNBAGAME-26FEB24MINPOR-MIN',
#   'title': 'Minnesota at Portland Winner?',
#   'updated_time': '2026-02-22T17:06:00.49251Z',
#   'volume': 6732,
#   'volume_24h': 6684,
#   'volume_24h_fp': '6684.00',
#   'volume_fp': '6732.00',
#   'yes_ask': 68,
#   'yes_ask_dollars': '0.6800',
#   'yes_bid': 66,
#   'yes_bid_dollars': '0.6600',
#   'yes_sub_title': 'Minnesota'},
#  {'can_close_early': True,
#   'close_time': '2026-03-11T01:00:00Z',
#   'created_time': '2026-02-22T17:02:49.110656Z',
#   'custom_strike': {'basketball_team': '5dc3fe01-79a4-4f2f-a953-d922ea4a6dd3'},
#   'early_close_condition': 'This market will close and expire after a winner is declared.',
#   'event_ticker': 'KXNBAGAME-26FEB24MIAMIL',
#   'expected_expiration_time': '2026-02-25T04:00:00Z',
#   'expiration_time': '2026-03-11T01:00:00Z',
#   'expiration_value': '',
#   'fractional_trading_enabled': False,
#   'last_price': 35,
#   'last_price_dollars': '0.3500',
#   'latest_expiration_time': '2026-03-11T01:00:00Z',
#   'liquidity': 0,
#   'liquidity_dollars': '0.0000',
#   'market_type': 'binary',
#   'no_ask': 67,
#   'no_ask_dollars': '0.6700',
#   'no_bid': 65,
#   'no_bid_dollars': '0.6500',
#   'no_sub_title': 'Milwaukee',
#   'notional_value': 100,
#   'notional_value_dollars': '1.0000',
#   'open_interest': 2022,
#   'open_interest_fp': '2022.00',
#   'open_time': '2026-02-22T17:06:00Z',
#   'previous_price': 0,
#   'previous_price_dollars': '0.0000',
#   'previous_yes_ask': 51,
#   'previous_yes_ask_dollars': '0.5100',
#   'previous_yes_bid': 32,
#   'previous_yes_bid_dollars': '0.3200',
#   'price_level_structure': 'linear_cent',
#   'price_ranges': [{'end': '1.0000', 'start': '0.0000', 'step': '0.0100'}],
#   'response_price_units': 'usd_cent',
#   'result': '',
#   'rules_primary': 'If Milwaukee wins the Miami at Milwaukee professional basketball game originally scheduled for Feb 24, 2026, then the market resolves to Yes.',
#   'rules_secondary': '',
#   'settlement_timer_seconds': 30,
#   'status': 'active',
#   'strike_type': 'structured',
#   'subtitle': '',
#   'tick_size': 1,
#   'ticker': 'KXNBAGAME-26FEB24MIAMIL-MIL',
#   'title': 'Miami at Milwaukee Winner?',
#   'updated_time': '2026-02-22T17:06:00.49251Z',
#   'volume': 2115,
#   'volume_24h': 2112,
#   'volume_24h_fp': '2112.00',
#   'volume_fp': '2115.00',
#   'yes_ask': 35,
#   'yes_ask_dollars': '0.3500',
#   'yes_bid': 33,
#   'yes_bid_dollars': '0.3300',
#   'yes_sub_title': 'Milwaukee'},
#  {'can_close_early': True,
#   'close_time': '2026-03-11T01:00:00Z',
#   'created_time': '2026-02-22T17:02:49.110656Z',
#   'custom_strike': {'basketball_team': 'a17e4a68-2999-4f60-b67e-3e80aa9e198b'},
#   'early_close_condition': 'This market will close and expire after a winner is declared.',
#   'event_ticker': 'KXNBAGAME-26FEB24MIAMIL',
#   'expected_expiration_time': '2026-02-25T04:00:00Z',
#   'expiration_time': '2026-03-11T01:00:00Z',
#   'expiration_value': '',
#   'fractional_trading_enabled': False,
#   'last_price': 67,
#   'last_price_dollars': '0.6700',
#   'latest_expiration_time': '2026-03-11T01:00:00Z',
#   'liquidity': 0,
#   'liquidity_dollars': '0.0000',
#   'market_type': 'binary',
#   'no_ask': 35,
#   'no_ask_dollars': '0.3500',
#   'no_bid': 33,
#   'no_bid_dollars': '0.3300',
#   'no_sub_title': 'Miami',
#   'notional_value': 100,
#   'notional_value_dollars': '1.0000',
#   'open_interest': 3097,
#   'open_interest_fp': '3097.00',
#   'open_time': '2026-02-22T17:06:00Z',
#   'previous_price': 0,
#   'previous_price_dollars': '0.0000',
#   'previous_yes_ask': 68,
#   'previous_yes_ask_dollars': '0.6800',
#   'previous_yes_bid': 49,
#   'previous_yes_bid_dollars': '0.4900',
#   'price_level_structure': 'linear_cent',
#   'price_ranges': [{'end': '1.0000', 'start': '0.0000', 'step': '0.0100'}],
#   'response_price_units': 'usd_cent',
#   'result': '',
#   'rules_primary': 'If Miami wins the Miami at Milwaukee professional basketball game originally scheduled for Feb 24, 2026, then the market resolves to Yes.',
#   'rules_secondary': '',
#   'settlement_timer_seconds': 30,
#   'status': 'active',
#   'strike_type': 'structured',
#   'subtitle': '',
#   'tick_size': 1,
#   'ticker': 'KXNBAGAME-26FEB24MIAMIL-MIA',
#   'title': 'Miami at Milwaukee Winner?',
#   'updated_time': '2026-02-22T17:06:00.49251Z',
#   'volume': 3173,
#   'volume_24h': 2861,
#   'volume_24h_fp': '2861.00',
#   'volume_fp': '3173.00',
#   'yes_ask': 67,
#   'yes_ask_dollars': '0.6700',
#   'yes_bid': 65,
#   'yes_bid_dollars': '0.6500',
#   'yes_sub_title': 'Miami'},
#  {'can_close_early': True,
#   'close_time': '2026-03-11T01:00:00Z',
#   'created_time': '2026-02-22T17:02:49.069047Z',
#   'custom_strike': {'basketball_team': '65f0250b-455d-43d7-b7dc-7d321bdf9abc'},
#   'early_close_condition': 'This market will close and expire after a winner is declared.',
#   'event_ticker': 'KXNBAGAME-26FEB24CHACHI',
#   'expected_expiration_time': '2026-02-25T04:00:00Z',
#   'expiration_time': '2026-03-11T01:00:00Z',
#   'expiration_value': '',
#   'fractional_trading_enabled': False,
#   'last_price': 30,
#   'last_price_dollars': '0.3000',
#   'latest_expiration_time': '2026-03-11T01:00:00Z',
#   'liquidity': 0,
#   'liquidity_dollars': '0.0000',
#   'market_type': 'binary',
#   'no_ask': 72,
#   'no_ask_dollars': '0.7200',
#   'no_bid': 70,
#   'no_bid_dollars': '0.7000',
#   'no_sub_title': 'Chicago',
#   'notional_value': 100,
#   'notional_value_dollars': '1.0000',
#   'open_interest': 6092,
#   'open_interest_fp': '6092.00',
#   'open_time': '2026-02-22T17:06:00Z',
#   'previous_price': 0,
#   'previous_price_dollars': '0.0000',
#   'previous_yes_ask': 46,
#   'previous_yes_ask_dollars': '0.4600',
#   'previous_yes_bid': 26,
#   'previous_yes_bid_dollars': '0.2600',
#   'price_level_structure': 'linear_cent',
#   'price_ranges': [{'end': '1.0000', 'start': '0.0000', 'step': '0.0100'}],
#   'response_price_units': 'usd_cent',
#   'result': '',
#   'rules_primary': 'If Chicago wins the Charlotte at Chicago professional basketball game originally scheduled for Feb 24, 2026, then the market resolves to Yes.',
#   'rules_secondary': '',
#   'settlement_timer_seconds': 30,
#   'status': 'active',
#   'strike_type': 'structured',
#   'subtitle': '',
#   'tick_size': 1,
#   'ticker': 'KXNBAGAME-26FEB24CHACHI-CHI',
#   'title': 'Charlotte at Chicago Winner?',
#   'updated_time': '2026-02-22T17:06:00.49251Z',
#   'volume': 6715,
#   'volume_24h': 6084,
#   'volume_24h_fp': '6084.00',
#   'volume_fp': '6715.00',
#   'yes_ask': 30,
#   'yes_ask_dollars': '0.3000',
#   'yes_bid': 28,
#   'yes_bid_dollars': '0.2800',
#   'yes_sub_title': 'Chicago'},
#  {'can_close_early': True,
#   'close_time': '2026-03-11T01:00:00Z',
#   'created_time': '2026-02-22T17:02:49.069047Z',
#   'custom_strike': {'basketball_team': '7c980c51-fa76-4571-b165-242b2a00f3a1'},
#   'early_close_condition': 'This market will close and expire after a winner is declared.',
#   'event_ticker': 'KXNBAGAME-26FEB24CHACHI',
#   'expected_expiration_time': '2026-02-25T04:00:00Z',
#   'expiration_time': '2026-03-11T01:00:00Z',
#   'expiration_value': '',
#   'fractional_trading_enabled': False,
#   'last_price': 71,
#   'last_price_dollars': '0.7100',
#   'latest_expiration_time': '2026-03-11T01:00:00Z',
#   'liquidity': 0,
#   'liquidity_dollars': '0.0000',
#   'market_type': 'binary',
#   'no_ask': 31,
#   'no_ask_dollars': '0.3100',
#   'no_bid': 29,
#   'no_bid_dollars': '0.2900',
#   'no_sub_title': 'Charlotte',
#   'notional_value': 100,
#   'notional_value_dollars': '1.0000',
#   'open_interest': 7904,
#   'open_interest_fp': '7904.00',
#   'open_time': '2026-02-22T17:06:00Z',
#   'previous_price': 0,
#   'previous_price_dollars': '0.0000',
#   'previous_yes_ask': 72,
#   'previous_yes_ask_dollars': '0.7200',
#   'previous_yes_bid': 71,
#   'previous_yes_bid_dollars': '0.7100',
#   'price_level_structure': 'linear_cent',
#   'price_ranges': [{'end': '1.0000', 'start': '0.0000', 'step': '0.0100'}],
#   'response_price_units': 'usd_cent',
#   'result': '',
#   'rules_primary': 'If Charlotte wins the Charlotte at Chicago professional basketball game originally scheduled for Feb 24, 2026, then the market resolves to Yes.',
#   'rules_secondary': '',
#   'settlement_timer_seconds': 30,
#   'status': 'active',
#   'strike_type': 'structured',
#   'subtitle': '',
#   'tick_size': 1,
#   'ticker': 'KXNBAGAME-26FEB24CHACHI-CHA',
#   'title': 'Charlotte at Chicago Winner?',
#   'updated_time': '2026-02-22T17:06:00.49251Z',
#   'volume': 7940,
#   'volume_24h': 7940,
#   'volume_24h_fp': '7940.00',
#   'volume_fp': '7940.00',
#   'yes_ask': 71,
#   'yes_ask_dollars': '0.7100',
#   'yes_bid': 69,
#   'yes_bid_dollars': '0.6900',
#   'yes_sub_title': 'Charlotte'},
#  {'can_close_early': True,
#   'close_time': '2026-03-11T02:00:00Z',
#   'created_time': '2026-02-22T17:02:48.883547Z',
#   'custom_strike': {'basketball_team': 'ace11dff-c5d1-4ab9-9452-5312253659fd'},
#   'early_close_condition': 'This market will close and expire after a winner is declared.',
#   'event_ticker': 'KXNBAGAME-26FEB24BOSPHX',
#   'expected_expiration_time': '2026-02-25T05:00:00Z',
#   'expiration_time': '2026-03-11T02:00:00Z',
#   'expiration_value': '',
#   'fractional_trading_enabled': False,
#   'last_price': 30,
#   'last_price_dollars': '0.3000',
#   'latest_expiration_time': '2026-03-11T02:00:00Z',
#   'liquidity': 0,
#   'liquidity_dollars': '0.0000',
#   'market_type': 'binary',
#   'no_ask': 72,
#   'no_ask_dollars': '0.7200',
#   'no_bid': 70,
#   'no_bid_dollars': '0.7000',
#   'no_sub_title': 'Phoenix',
#   'notional_value': 100,
#   'notional_value_dollars': '1.0000',
#   'open_interest': 5357,
#   'open_interest_fp': '5357.00',
#   'open_time': '2026-02-22T17:06:00Z',
#   'previous_price': 0,
#   'previous_price_dollars': '0.0000',
#   'previous_yes_ask': 45,
#   'previous_yes_ask_dollars': '0.4500',
#   'previous_yes_bid': 26,
#   'previous_yes_bid_dollars': '0.2600',
#   'price_level_structure': 'linear_cent',
#   'price_ranges': [{'end': '1.0000', 'start': '0.0000', 'step': '0.0100'}],
#   'response_price_units': 'usd_cent',
#   'result': '',
#   'rules_primary': 'If Phoenix wins the Boston at Phoenix professional basketball game originally scheduled for Feb 24, 2026, then the market resolves to Yes.',
#   'rules_secondary': '',
#   'settlement_timer_seconds': 30,
#   'status': 'active',
#   'strike_type': 'structured',
#   'subtitle': '',
#   'tick_size': 1,
#   'ticker': 'KXNBAGAME-26FEB24BOSPHX-PHX',
#   'title': 'Boston at Phoenix Winner?',
#   'updated_time': '2026-02-22T17:06:00.49251Z',
#   'volume': 6045,
#   'volume_24h': 5980,
#   'volume_24h_fp': '5980.00',
#   'volume_fp': '6045.00',
#   'yes_ask': 30,
#   'yes_ask_dollars': '0.3000',
#   'yes_bid': 28,
#   'yes_bid_dollars': '0.2800',
#   'yes_sub_title': 'Phoenix'},
#  {'can_close_early': True,
#   'close_time': '2026-03-11T02:00:00Z',
#   'created_time': '2026-02-22T17:02:48.883547Z',
#   'custom_strike': {'basketball_team': '6dd427f5-fa02-40ef-aa90-cfa73e0c539e'},
#   'early_close_condition': 'This market will close and expire after a winner is declared.',
#   'event_ticker': 'KXNBAGAME-26FEB24BOSPHX',
#   'expected_expiration_time': '2026-02-25T05:00:00Z',
#   'expiration_time': '2026-03-11T02:00:00Z',
#   'expiration_value': '',
#   'fractional_trading_enabled': False,
#   'last_price': 73,
#   'last_price_dollars': '0.7300',
#   'latest_expiration_time': '2026-03-11T02:00:00Z',
#   'liquidity': 0,
#   'liquidity_dollars': '0.0000',
#   'market_type': 'binary',
#   'no_ask': 29,
#   'no_ask_dollars': '0.2900',
#   'no_bid': 27,
#   'no_bid_dollars': '0.2700',
#   'no_sub_title': 'Boston',
#   'notional_value': 100,
#   'notional_value_dollars': '1.0000',
#   'open_interest': 36726,
#   'open_interest_fp': '36726.00',
#   'open_time': '2026-02-22T17:06:00Z',
#   'previous_price': 0,
#   'previous_price_dollars': '0.0000',
#   'previous_yes_ask': 68,
#   'previous_yes_ask_dollars': '0.6800',
#   'previous_yes_bid': 54,
#   'previous_yes_bid_dollars': '0.5400',
#   'price_level_structure': 'linear_cent',
#   'price_ranges': [{'end': '1.0000', 'start': '0.0000', 'step': '0.0100'}],
#   'response_price_units': 'usd_cent',
#   'result': '',
#   'rules_primary': 'If Boston wins the Boston at Phoenix professional basketball game originally scheduled for Feb 24, 2026, then the market resolves to Yes.',
#   'rules_secondary': '',
#   'settlement_timer_seconds': 30,
#   'status': 'active',
#   'strike_type': 'structured',
#   'subtitle': '',
#   'tick_size': 1,
#   'ticker': 'KXNBAGAME-26FEB24BOSPHX-BOS',
#   'title': 'Boston at Phoenix Winner?',
#   'updated_time': '2026-02-22T17:06:00.49251Z',
#   'volume': 43443,
#   'volume_24h': 41674,
#   'volume_24h_fp': '41674.00',
#   'volume_fp': '43443.00',
#   'yes_ask': 73,
#   'yes_ask_dollars': '0.7300',
#   'yes_bid': 71,
#   'yes_bid_dollars': '0.7100',
#   'yes_sub_title': 'Boston'},
#  {'can_close_early': True,
#   'close_time': '2026-03-11T01:00:00Z',
#   'created_time': '2026-02-22T17:02:48.348398Z',
#   'custom_strike': {'basketball_team': 'd3c8c2ac-c4a0-4d67-8b16-53cb91118dfc'},
#   'early_close_condition': 'This market will close and expire after a winner is declared.',
#   'event_ticker': 'KXNBAGAME-26FEB24GSWNOP',
#   'expected_expiration_time': '2026-02-25T04:00:00Z',
#   'expiration_time': '2026-03-11T01:00:00Z',
#   'expiration_value': '',
#   'fractional_trading_enabled': False,
#   'last_price': 45,
#   'last_price_dollars': '0.4500',
#   'latest_expiration_time': '2026-03-11T01:00:00Z',
#   'liquidity': 0,
#   'liquidity_dollars': '0.0000',
#   'market_type': 'binary',
#   'no_ask': 56,
#   'no_ask_dollars': '0.5600',
#   'no_bid': 55,
#   'no_bid_dollars': '0.5500',
#   'no_sub_title': 'New Orleans',
#   'notional_value': 100,
#   'notional_value_dollars': '1.0000',
#   'open_interest': 6579,
#   'open_interest_fp': '6579.00',
#   'open_time': '2026-02-22T17:06:00Z',
#   'previous_price': 48,
#   'previous_price_dollars': '0.4800',
#   'previous_yes_ask': 47,
#   'previous_yes_ask_dollars': '0.4700',
#   'previous_yes_bid': 31,
#   'previous_yes_bid_dollars': '0.3100',
#   'price_level_structure': 'linear_cent',
#   'price_ranges': [{'end': '1.0000', 'start': '0.0000', 'step': '0.0100'}],
#   'response_price_units': 'usd_cent',
#   'result': '',
#   'rules_primary': 'If New Orleans wins the Golden State at New Orleans professional basketball game originally scheduled for Feb 24, 2026, then the market resolves to Yes.',
#   'rules_secondary': '',
#   'settlement_timer_seconds': 30,
#   'status': 'active',
#   'strike_type': 'structured',
#   'subtitle': '',
#   'tick_size': 1,
#   'ticker': 'KXNBAGAME-26FEB24GSWNOP-NOP',
#   'title': 'Golden State at New Orleans Winner?',
#   'updated_time': '2026-02-22T17:06:00.49251Z',
#   'volume': 6971,
#   'volume_24h': 6951,
#   'volume_24h_fp': '6951.00',
#   'volume_fp': '6971.00',
#   'yes_ask': 45,
#   'yes_ask_dollars': '0.4500',
#   'yes_bid': 44,
#   'yes_bid_dollars': '0.4400',
#   'yes_sub_title': 'New Orleans'},
#  {'can_close_early': True,
#   'close_time': '2026-03-11T01:00:00Z',
#   'created_time': '2026-02-22T17:02:48.348398Z',
#   'custom_strike': {'basketball_team': '502c629b-4da7-40fd-92ab-20cb55411c35'},
#   'early_close_condition': 'This market will close and expire after a winner is declared.',
#   'event_ticker': 'KXNBAGAME-26FEB24GSWNOP',
#   'expected_expiration_time': '2026-02-25T04:00:00Z',
#   'expiration_time': '2026-03-11T01:00:00Z',
#   'expiration_value': '',
#   'fractional_trading_enabled': False,
#   'last_price': 55,
#   'last_price_dollars': '0.5500',
#   'latest_expiration_time': '2026-03-11T01:00:00Z',
#   'liquidity': 0,
#   'liquidity_dollars': '0.0000',
#   'market_type': 'binary',
#   'no_ask': 46,
#   'no_ask_dollars': '0.4600',
#   'no_bid': 45,
#   'no_bid_dollars': '0.4500',
#   'no_sub_title': 'Golden State',
#   'notional_value': 100,
#   'notional_value_dollars': '1.0000',
#   'open_interest': 30391,
#   'open_interest_fp': '30391.00',
#   'open_time': '2026-02-22T17:06:00Z',
#   'previous_price': 0,
#   'previous_price_dollars': '0.0000',
#   'previous_yes_ask': 71,
#   'previous_yes_ask_dollars': '0.7100',
#   'previous_yes_bid': 52,
#   'previous_yes_bid_dollars': '0.5200',
#   'price_level_structure': 'linear_cent',
#   'price_ranges': [{'end': '1.0000', 'start': '0.0000', 'step': '0.0100'}],
#   'response_price_units': 'usd_cent',
#   'result': '',
#   'rules_primary': 'If Golden State wins the Golden State at New Orleans professional basketball game originally scheduled for Feb 24, 2026, then the market resolves to Yes.',
#   'rules_secondary': '',
#   'settlement_timer_seconds': 30,
#   'status': 'active',
#   'strike_type': 'structured',
#   'subtitle': '',
#   'tick_size': 1,
#   'ticker': 'KXNBAGAME-26FEB24GSWNOP-GSW',
#   'title': 'Golden State at New Orleans Winner?',
#   'updated_time': '2026-02-22T17:06:00.49251Z',
#   'volume': 32496,
#   'volume_24h': 32457,
#   'volume_24h_fp': '32457.00',
#   'volume_fp': '32496.00',
#   'yes_ask': 55,
#   'yes_ask_dollars': '0.5500',
#   'yes_bid': 54,
#   'yes_bid_dollars': '0.5400',
#   'yes_sub_title': 'Golden State'},
#  {'can_close_early': True,
#   'close_time': '2026-03-11T00:30:00Z',
# ...
#   'custom_strike': {'basketball_team': '0554528d-586b-461f-827b-801cf93e8a8e'},
#   'early_close_condition': 'This market will close and expire after a winner is declared.',
#   'event_ticker': 'KXNBAGAME-26FEB24PHIIND',
#   'expected_expiration_time': '2026-02-25T03:00:00Z',
#   'expiration_time': '2026-03-11T00:00:00Z',
#   'expiration_value': '',
#   'fractional_trading_enabled': False,
#   'last_price': 73,
#   'last_price_dollars': '0.7300',
#   'latest_expiration_time': '2026-03-11T00:00:00Z',
#   'liquidity': 0,
#   'liquidity_dollars': '0.0000',
#   'market_type': 'binary',
#   'no_ask': 29,
#   'no_ask_dollars': '0.2900',
#   'no_bid': 27,
#   'no_bid_dollars': '0.2700',
#   'no_sub_title': 'Philadelphia',
#   'notional_value': 100,
#   'notional_value_dollars': '1.0000',
#   'open_interest': 29379,
#   'open_interest_fp': '29379.00',
#   'open_time': '2026-02-22T14:06:00Z',
#   'previous_price': 73,
#   'previous_price_dollars': '0.7300',
#   'previous_yes_ask': 73,
#   'previous_yes_ask_dollars': '0.7300',
#   'previous_yes_bid': 70,
#   'previous_yes_bid_dollars': '0.7000',
#   'price_level_structure': 'linear_cent',
#   'price_ranges': [{'end': '1.0000', 'start': '0.0000', 'step': '0.0100'}],
#   'response_price_units': 'usd_cent',
#   'result': '',
#   'rules_primary': 'If Philadelphia wins the Philadelphia at Indiana professional basketball game originally scheduled for Feb 24, 2026, then the market resolves to Yes.',
#   'rules_secondary': '',
#   'settlement_timer_seconds': 30,
#   'status': 'active',
#   'strike_type': 'structured',
#   'subtitle': '',
#   'tick_size': 1,
#   'ticker': 'KXNBAGAME-26FEB24PHIIND-PHI',
#   'title': 'Philadelphia at Indiana Winner?',
#   'updated_time': '2026-02-22T14:06:00.492756Z',
#   'volume': 30272,
#   'volume_24h': 29328,
#   'volume_24h_fp': '29328.00',
#   'volume_fp': '30272.00',
#   'yes_ask': 73,
#   'yes_ask_dollars': '0.7300',
#   'yes_bid': 71,
#   'yes_bid_dollars': '0.7100',
#   'yes_sub_title': 'Philadelphia'},
#  {'can_close_early': True,
#   'close_time': '2026-03-11T00:00:00Z',
#   'created_time': '2026-02-22T14:01:47.907784Z',
#   'custom_strike': {'basketball_team': 'd059bab2-9fb5-42dd-8038-5a12474300ce'},
#   'early_close_condition': 'This market will close and expire after a winner is declared.',
#   'event_ticker': 'KXNBAGAME-26FEB24PHIIND',
#   'expected_expiration_time': '2026-02-25T03:00:00Z',
#   'expiration_time': '2026-03-11T00:00:00Z',
#   'expiration_value': '',
#   'fractional_trading_enabled': False,
#   'last_price': 29,
#   'last_price_dollars': '0.2900',
#   'latest_expiration_time': '2026-03-11T00:00:00Z',
#   'liquidity': 0,
#   'liquidity_dollars': '0.0000',
#   'market_type': 'binary',
#   'no_ask': 73,
#   'no_ask_dollars': '0.7300',
#   'no_bid': 71,
#   'no_bid_dollars': '0.7100',
#   'no_sub_title': 'Indiana',
#   'notional_value': 100,
#   'notional_value_dollars': '1.0000',
#   'open_interest': 3539,
#   'open_interest_fp': '3539.00',
#   'open_time': '2026-02-22T14:06:00Z',
#   'previous_price': 30,
#   'previous_price_dollars': '0.3000',
#   'previous_yes_ask': 30,
#   'previous_yes_ask_dollars': '0.3000',
#   'previous_yes_bid': 27,
#   'previous_yes_bid_dollars': '0.2700',
#   'price_level_structure': 'linear_cent',
#   'price_ranges': [{'end': '1.0000', 'start': '0.0000', 'step': '0.0100'}],
#   'response_price_units': 'usd_cent',
#   'result': '',
#   'rules_primary': 'If Indiana wins the Philadelphia at Indiana professional basketball game originally scheduled for Feb 24, 2026, then the market resolves to Yes.',
#   'rules_secondary': '',
#   'settlement_timer_seconds': 30,
#   'status': 'active',
#   'strike_type': 'structured',
#   'subtitle': '',
#   'tick_size': 1,
#   'ticker': 'KXNBAGAME-26FEB24PHIIND-IND',
#   'title': 'Philadelphia at Indiana Winner?',
#   'updated_time': '2026-02-22T14:06:00.492756Z',
#   'volume': 4713,
#   'volume_24h': 4557,
#   'volume_24h_fp': '4557.00',
#   'volume_fp': '4713.00',
#   'yes_ask': 29,
#   'yes_ask_dollars': '0.2900',
#   'yes_bid': 27,
#   'yes_bid_dollars': '0.2700',
#   'yes_sub_title': 'Indiana'},
#  {'can_close_early': True,
#   'close_time': '2026-03-10T01:00:00Z',
#   'created_time': '2026-02-21T17:02:38.629776Z',
#   'custom_strike': {'basketball_team': 'ab9e2e9a-3243-41b6-a291-95f4d9c6edf7'},
#   'early_close_condition': 'This market will close and expire after a winner is declared.',
#   'event_ticker': 'KXNBAGAME-26FEB23SACMEM',
#   'expected_expiration_time': '2026-02-24T04:00:00Z',
#   'expiration_time': '2026-03-10T01:00:00Z',
#   'expiration_value': '',
#   'fractional_trading_enabled': False,
#   'last_price': 43,
#   'last_price_dollars': '0.4300',
#   'latest_expiration_time': '2026-03-10T01:00:00Z',
#   'liquidity': 0,
#   'liquidity_dollars': '0.0000',
#   'market_type': 'binary',
#   'no_ask': 59,
#   'no_ask_dollars': '0.5900',
#   'no_bid': 57,
#   'no_bid_dollars': '0.5700',
#   'no_sub_title': 'Sacramento',
#   'notional_value': 100,
#   'notional_value_dollars': '1.0000',
#   'open_interest': 115601,
#   'open_interest_fp': '115601.00',
#   'open_time': '2026-02-21T17:07:00Z',
#   'previous_price': 31,
#   'previous_price_dollars': '0.3100',
#   'previous_yes_ask': 31,
#   'previous_yes_ask_dollars': '0.3100',
#   'previous_yes_bid': 29,
#   'previous_yes_bid_dollars': '0.2900',
#   'price_level_structure': 'linear_cent',
#   'price_ranges': [{'end': '1.0000', 'start': '0.0000', 'step': '0.0100'}],
#   'response_price_units': 'usd_cent',
#   'result': '',
#   'rules_primary': 'If Sacramento wins the Sacramento at Memphis professional basketball game originally scheduled for Feb 23, 2026, then the market resolves to Yes.',
#   'rules_secondary': '',
#   'settlement_timer_seconds': 30,
#   'status': 'active',
#   'strike_type': 'structured',
#   'subtitle': '',
#   'tick_size': 1,
#   'ticker': 'KXNBAGAME-26FEB23SACMEM-SAC',
#   'title': 'Sacramento at Memphis Winner?',
#   'updated_time': '2026-02-21T17:07:00.492164Z',
#   'volume': 125475,
#   'volume_24h': 111167,
#   'volume_24h_fp': '111167.00',
#   'volume_fp': '125475.00',
#   'yes_ask': 43,
#   'yes_ask_dollars': '0.4300',
#   'yes_bid': 41,
#   'yes_bid_dollars': '0.4100',
#   'yes_sub_title': 'Sacramento'},
#  {'can_close_early': True,
#   'close_time': '2026-03-10T01:00:00Z',
#   'created_time': '2026-02-21T17:02:38.629776Z',
#   'custom_strike': {'basketball_team': '1cfe70b8-4dfc-47dc-acca-b68d4a725972'},
#   'early_close_condition': 'This market will close and expire after a winner is declared.',
#   'event_ticker': 'KXNBAGAME-26FEB23SACMEM',
#   'expected_expiration_time': '2026-02-24T04:00:00Z',
#   'expiration_time': '2026-03-10T01:00:00Z',
#   'expiration_value': '',
#   'fractional_trading_enabled': False,
#   'last_price': 59,
#   'last_price_dollars': '0.5900',
#   'latest_expiration_time': '2026-03-10T01:00:00Z',
#   'liquidity': 0,
#   'liquidity_dollars': '0.0000',
#   'market_type': 'binary',
#   'no_ask': 43,
#   'no_ask_dollars': '0.4300',
#   'no_bid': 41,
#   'no_bid_dollars': '0.4100',
#   'no_sub_title': 'Memphis',
#   'notional_value': 100,
#   'notional_value_dollars': '1.0000',
#   'open_interest': 249236,
#   'open_interest_fp': '249236.00',
#   'open_time': '2026-02-21T17:07:00Z',
#   'previous_price': 69,
#   'previous_price_dollars': '0.6900',
#   'previous_yes_ask': 69,
#   'previous_yes_ask_dollars': '0.6900',
#   'previous_yes_bid': 68,
#   'previous_yes_bid_dollars': '0.6800',
#   'price_level_structure': 'linear_cent',
#   'price_ranges': [{'end': '1.0000', 'start': '0.0000', 'step': '0.0100'}],
#   'response_price_units': 'usd_cent',
#   'result': '',
#   'rules_primary': 'If Memphis wins the Sacramento at Memphis professional basketball game originally scheduled for Feb 23, 2026, then the market resolves to Yes.',
#   'rules_secondary': '',
#   'settlement_timer_seconds': 30,
#   'status': 'active',
#   'strike_type': 'structured',
#   'subtitle': '',
#   'tick_size': 1,
#   'ticker': 'KXNBAGAME-26FEB23SACMEM-MEM',
#   'title': 'Sacramento at Memphis Winner?',
#   'updated_time': '2026-02-21T17:07:00.492164Z',
#   'volume': 296801,
#   'volume_24h': 273878,
#   'volume_24h_fp': '273878.00',
#   'volume_fp': '296801.00',
#   'yes_ask': 59,
#   'yes_ask_dollars': '0.5900',
#   'yes_bid': 57,
#   'yes_bid_dollars': '0.5700',
#   'yes_sub_title': 'Memphis'},
#  {'can_close_early': True,
#   'close_time': '2026-03-10T02:30:00Z',
#   'created_time': '2026-02-21T17:02:38.489863Z',
#   'custom_strike': {'basketball_team': '6f60dfb1-fda1-423f-b76f-67e9d24b9644'},
#   'early_close_condition': 'This market will close and expire after a winner is declared.',
#   'event_ticker': 'KXNBAGAME-26FEB23UTAHOU',
#   'expected_expiration_time': '2026-02-24T05:30:00Z',
#   'expiration_time': '2026-03-10T02:30:00Z',
#   'expiration_value': '',
#   'fractional_trading_enabled': False,
#   'last_price': 14,
#   'last_price_dollars': '0.1400',
#   'latest_expiration_time': '2026-03-10T02:30:00Z',
#   'liquidity': 0,
#   'liquidity_dollars': '0.0000',
#   'market_type': 'binary',
#   'no_ask': 88,
#   'no_ask_dollars': '0.8800',
#   'no_bid': 86,
#   'no_bid_dollars': '0.8600',
#   'no_sub_title': 'Utah',
#   'notional_value': 100,
#   'notional_value_dollars': '1.0000',
#   'open_interest': 193719,
#   'open_interest_fp': '193719.00',
#   'open_time': '2026-02-21T17:07:00Z',
#   'previous_price': 15,
#   'previous_price_dollars': '0.1500',
#   'previous_yes_ask': 15,
#   'previous_yes_ask_dollars': '0.1500',
#   'previous_yes_bid': 14,
#   'previous_yes_bid_dollars': '0.1400',
#   'price_level_structure': 'linear_cent',
#   'price_ranges': [{'end': '1.0000', 'start': '0.0000', 'step': '0.0100'}],
#   'response_price_units': 'usd_cent',
#   'result': '',
#   'rules_primary': 'If Utah wins the Utah at Houston professional basketball game originally scheduled for Feb 23, 2026, then the market resolves to Yes.',
#   'rules_secondary': '',
#   'settlement_timer_seconds': 30,
#   'status': 'active',
#   'strike_type': 'structured',
#   'subtitle': '',
#   'tick_size': 1,
#   'ticker': 'KXNBAGAME-26FEB23UTAHOU-UTA',
#   'title': 'Utah at Houston Winner?',
#   'updated_time': '2026-02-21T17:07:00.492164Z',
#   'volume': 200050,
#   'volume_24h': 194280,
#   'volume_24h_fp': '194280.00',
#   'volume_fp': '200050.00',
#   'yes_ask': 14,
#   'yes_ask_dollars': '0.1400',
#   'yes_bid': 12,
#   'yes_bid_dollars': '0.1200',
#   'yes_sub_title': 'Utah'},
#  {'can_close_early': True,
#   'close_time': '2026-03-10T02:30:00Z',
#   'created_time': '2026-02-21T17:02:38.489863Z',
#   'custom_strike': {'basketball_team': 'a8625e4b-4ae6-4062-a7c1-0b6e1f4ae211'},
#   'early_close_condition': 'This market will close and expire after a winner is declared.',
#   'event_ticker': 'KXNBAGAME-26FEB23UTAHOU',
#   'expected_expiration_time': '2026-02-24T05:30:00Z',
#   'expiration_time': '2026-03-10T02:30:00Z',
#   'expiration_value': '',
#   'fractional_trading_enabled': False,
#   'last_price': 87,
#   'last_price_dollars': '0.8700',
#   'latest_expiration_time': '2026-03-10T02:30:00Z',
#   'liquidity': 0,
#   'liquidity_dollars': '0.0000',
#   'market_type': 'binary',
#   'no_ask': 14,
#   'no_ask_dollars': '0.1400',
#   'no_bid': 13,
#   'no_bid_dollars': '0.1300',
#   'no_sub_title': 'Houston',
#   'notional_value': 100,
#   'notional_value_dollars': '1.0000',
#   'open_interest': 194593,
#   'open_interest_fp': '194593.00',
#   'open_time': '2026-02-21T17:07:00Z',
#   'previous_price': 88,
#   'previous_price_dollars': '0.8800',
#   'previous_yes_ask': 88,
#   'previous_yes_ask_dollars': '0.8800',
#   'previous_yes_bid': 86,
#   'previous_yes_bid_dollars': '0.8600',
#   'price_level_structure': 'linear_cent',
#   'price_ranges': [{'end': '1.0000', 'start': '0.0000', 'step': '0.0100'}],
#   'response_price_units': 'usd_cent',
#   'result': '',
#   'rules_primary': 'If Houston wins the Utah at Houston professional basketball game originally scheduled for Feb 23, 2026, then the market resolves to Yes.',
#   'rules_secondary': '',
#   'settlement_timer_seconds': 30,
#   'status': 'active',
#   'strike_type': 'structured',
#   'subtitle': '',
#   'tick_size': 1,
#   'ticker': 'KXNBAGAME-26FEB23UTAHOU-HOU',
#   'title': 'Utah at Houston Winner?',
#   'updated_time': '2026-02-21T17:07:00.492164Z',
#   'volume': 209075,
#   'volume_24h': 198453,
#   'volume_24h_fp': '198453.00',
#   'volume_fp': '209075.00',
#   'yes_ask': 87,
#   'yes_ask_dollars': '0.8700',
#   'yes_bid': 86,
#   'yes_bid_dollars': '0.8600',
#   'yes_sub_title': 'Houston'},
#  {'can_close_early': True,
#   'close_time': '2026-03-10T00:00:00Z',
#   'created_time': '2026-02-21T14:02:14.746077Z',
#   'custom_strike': {'basketball_team': 'ad36c3e8-4194-4e63-920f-7c50f46191a6'},
#   'early_close_condition': 'This market will close and expire after a winner is declared.',
#   'event_ticker': 'KXNBAGAME-26FEB23SASDET',
#   'expected_expiration_time': '2026-02-24T03:00:00Z',
#   'expiration_time': '2026-03-10T00:00:00Z',
#   'expiration_value': '',
#   'fractional_trading_enabled': False,
#   'last_price': 49,
#   'last_price_dollars': '0.4900',
#   'latest_expiration_time': '2026-03-10T00:00:00Z',
#   'liquidity': 0,
#   'liquidity_dollars': '0.0000',
#   'market_type': 'binary',
#   'no_ask': 52,
#   'no_ask_dollars': '0.5200',
#   'no_bid': 51,
#   'no_bid_dollars': '0.5100',
#   'no_sub_title': 'San Antonio',
#   'notional_value': 100,
#   'notional_value_dollars': '1.0000',
#   'open_interest': 453075,
#   'open_interest_fp': '453075.00',
#   'open_time': '2026-02-21T14:06:00Z',
#   'previous_price': 48,
#   'previous_price_dollars': '0.4800',
#   'previous_yes_ask': 48,
#   'previous_yes_ask_dollars': '0.4800',
#   'previous_yes_bid': 46,
#   'previous_yes_bid_dollars': '0.4600',
#   'price_level_structure': 'linear_cent',
#   'price_ranges': [{'end': '1.0000', 'start': '0.0000', 'step': '0.0100'}],
#   'response_price_units': 'usd_cent',
#   'result': '',
#   'rules_primary': 'If San Antonio wins the San Antonio at Detroit professional basketball game originally scheduled for Feb 23, 2026, then the market resolves to Yes.',
#   'rules_secondary': '',
#   'settlement_timer_seconds': 30,
#   'status': 'active',
#   'strike_type': 'structured',
#   'subtitle': '',
#   'tick_size': 1,
#   'ticker': 'KXNBAGAME-26FEB23SASDET-SAS',
#   'title': 'San Antonio at Detroit Winner?',
#   'updated_time': '2026-02-21T14:06:00.493059Z',
#   'volume': 467583,
#   'volume_24h': 443739,
#   'volume_24h_fp': '443739.00',
#   'volume_fp': '467583.00',
#   'yes_ask': 49,
#   'yes_ask_dollars': '0.4900',
#   'yes_bid': 48,
#   'yes_bid_dollars': '0.4800',
#   'yes_sub_title': 'San Antonio'},
#  {'can_close_early': True,
#   'close_time': '2026-03-10T00:00:00Z',
#   'created_time': '2026-02-21T14:02:14.746077Z',
#   'custom_strike': {'basketball_team': '65569528-1888-40aa-9d62-2b0e8142a9b4'},
#   'early_close_condition': 'This market will close and expire after a winner is declared.',
#   'event_ticker': 'KXNBAGAME-26FEB23SASDET',
#   'expected_expiration_time': '2026-02-24T03:00:00Z',
#   'expiration_time': '2026-03-10T00:00:00Z',
#   'expiration_value': '',
#   'fractional_trading_enabled': False,
#   'last_price': 53,
#   'last_price_dollars': '0.5300',
#   'latest_expiration_time': '2026-03-10T00:00:00Z',
#   'liquidity': 0,
#   'liquidity_dollars': '0.0000',
#   'market_type': 'binary',
#   'no_ask': 48,
#   'no_ask_dollars': '0.4800',
#   'no_bid': 47,
#   'no_bid_dollars': '0.4700',
#   'no_sub_title': 'Detroit',
#   'notional_value': 100,
#   'notional_value_dollars': '1.0000',
#   'open_interest': 469326,
#   'open_interest_fp': '469326.00',
#   'open_time': '2026-02-21T14:06:00Z',
#   'previous_price': 55,
#   'previous_price_dollars': '0.5500',
#   'previous_yes_ask': 55,
#   'previous_yes_ask_dollars': '0.5500',
#   'previous_yes_bid': 54,
#   'previous_yes_bid_dollars': '0.5400',
#   'price_level_structure': 'linear_cent',
#   'price_ranges': [{'end': '1.0000', 'start': '0.0000', 'step': '0.0100'}],
#   'response_price_units': 'usd_cent',
#   'result': '',
#   'rules_primary': 'If Detroit wins the San Antonio at Detroit professional basketball game originally scheduled for Feb 23, 2026, then the market resolves to Yes.',
#   'rules_secondary': '',
#   'settlement_timer_seconds': 30,
#   'status': 'active',
#   'strike_type': 'structured',
#   'subtitle': '',
#   'tick_size': 1,
#   'ticker': 'KXNBAGAME-26FEB23SASDET-DET',
#   'title': 'San Antonio at Detroit Winner?',
#   'updated_time': '2026-02-21T14:06:00.493059Z',
#   'volume': 492401,
#   'volume_24h': 472862,
#   'volume_24h_fp': '472862.00',
#   'volume_fp': '492401.00',
#   'yes_ask': 53,
#   'yes_ask_dollars': '0.5300',
#   'yes_bid': 52,
#   'yes_bid_dollars': '0.5200',
#   'yes_sub_title': 'Detroit'}]

# %%
# Lets take a closer look at the knicks game 
# Get details for event_ticker: KXNBAGAME-26FEB24NYKCLE 
event = "KXNBAGAME-26FEB24NYKCLE"

event_markets = [
    m for m in markets_data["markets"]
    if m.get("event_ticker") == event
]
event_markets  # list of all markets in that event
# Out:
# [{'can_close_early': True,
#   'close_time': '2026-03-11T00:30:00Z',
#   'created_time': '2026-02-22T17:02:45.355229Z',
#   'custom_strike': {'basketball_team': '67468ecc-b868-43a4-b9dc-751a52894bb0'},
#   'early_close_condition': 'This market will close and expire after a winner is declared.',
#   'event_ticker': 'KXNBAGAME-26FEB24NYKCLE',
#   'expected_expiration_time': '2026-02-25T03:30:00Z',
#   'expiration_time': '2026-03-11T00:30:00Z',
#   'expiration_value': '',
#   'fractional_trading_enabled': False,
#   'last_price': 41,
#   'last_price_dollars': '0.4100',
#   'latest_expiration_time': '2026-03-11T00:30:00Z',
#   'liquidity': 0,
#   'liquidity_dollars': '0.0000',
#   'market_type': 'binary',
#   'no_ask': 60,
#   'no_ask_dollars': '0.6000',
#   'no_bid': 59,
#   'no_bid_dollars': '0.5900',
#   'no_sub_title': 'New York',
#   'notional_value': 100,
#   'notional_value_dollars': '1.0000',
#   'open_interest': 24310,
#   'open_interest_fp': '24310.00',
#   'open_time': '2026-02-22T17:06:00Z',
#   'previous_price': 51,
#   'previous_price_dollars': '0.5100',
#   'previous_yes_ask': 51,
#   'previous_yes_ask_dollars': '0.5100',
#   'previous_yes_bid': 36,
#   'previous_yes_bid_dollars': '0.3600',
#   'price_level_structure': 'linear_cent',
#   'price_ranges': [{'end': '1.0000', 'start': '0.0000', 'step': '0.0100'}],
#   'response_price_units': 'usd_cent',
#   'result': '',
#   'rules_primary': 'If New York wins the New York at Cleveland professional basketball game originally scheduled for Feb 24, 2026, then the market resolves to Yes.',
#   'rules_secondary': '',
#   'settlement_timer_seconds': 30,
#   'status': 'active',
#   'strike_type': 'structured',
#   'subtitle': '',
#   'tick_size': 1,
#   'ticker': 'KXNBAGAME-26FEB24NYKCLE-NYK',
#   'title': 'New York at Cleveland Winner?',
#   'updated_time': '2026-02-22T17:06:00.49251Z',
#   'volume': 28441,
#   'volume_24h': 28200,
#   'volume_24h_fp': '28200.00',
#   'volume_fp': '28441.00',
#   'yes_ask': 41,
#   'yes_ask_dollars': '0.4100',
#   'yes_bid': 40,
#   'yes_bid_dollars': '0.4000',
#   'yes_sub_title': 'New York'},
#  {'can_close_early': True,
#   'close_time': '2026-03-11T00:30:00Z',
#   'created_time': '2026-02-22T17:02:45.355229Z',
#   'custom_strike': {'basketball_team': '90381a35-42a6-4975-851f-175418e4271a'},
#   'early_close_condition': 'This market will close and expire after a winner is declared.',
#   'event_ticker': 'KXNBAGAME-26FEB24NYKCLE',
#   'expected_expiration_time': '2026-02-25T03:30:00Z',
#   'expiration_time': '2026-03-11T00:30:00Z',
#   'expiration_value': '',
#   'fractional_trading_enabled': False,
#   'last_price': 62,
#   'last_price_dollars': '0.6200',
#   'latest_expiration_time': '2026-03-11T00:30:00Z',
#   'liquidity': 0,
#   'liquidity_dollars': '0.0000',
#   'market_type': 'binary',
#   'no_ask': 40,
#   'no_ask_dollars': '0.4000',
#   'no_bid': 38,
#   'no_bid_dollars': '0.3800',
#   'no_sub_title': 'Cleveland',
#   'notional_value': 100,
#   'notional_value_dollars': '1.0000',
#   'open_interest': 15223,
#   'open_interest_fp': '15223.00',
#   'open_time': '2026-02-22T17:06:00Z',
#   'previous_price': 65,
#   'previous_price_dollars': '0.6500',
#   'previous_yes_ask': 65,
#   'previous_yes_ask_dollars': '0.6500',
#   'previous_yes_bid': 61,
#   'previous_yes_bid_dollars': '0.6100',
#   'price_level_structure': 'linear_cent',
#   'price_ranges': [{'end': '1.0000', 'start': '0.0000', 'step': '0.0100'}],
#   'response_price_units': 'usd_cent',
#   'result': '',
#   'rules_primary': 'If Cleveland wins the New York at Cleveland professional basketball game originally scheduled for Feb 24, 2026, then the market resolves to Yes.',
#   'rules_secondary': '',
#   'settlement_timer_seconds': 30,
#   'status': 'active',
#   'strike_type': 'structured',
#   'subtitle': '',
#   'tick_size': 1,
#   'ticker': 'KXNBAGAME-26FEB24NYKCLE-CLE',
#   'title': 'New York at Cleveland Winner?',
#   'updated_time': '2026-02-22T17:06:00.49251Z',
#   'volume': 16957,
#   'volume_24h': 16436,
#   'volume_24h_fp': '16436.00',
#   'volume_fp': '16957.00',
#   'yes_ask': 62,
#   'yes_ask_dollars': '0.6200',
#   'yes_bid': 60,
#   'yes_bid_dollars': '0.6000',
#   'yes_sub_title': 'Cleveland'}]

# %% [markdown]
# ##### Closer look at the output
#
# You’ve got two separate binary markets inside the same event (`KXNBAGAME-26FEB24NYKCLE`). Each market answers the same question (“Winner?”) but with a different team as “YES”.
#
# What are the different markets here?
# 1) `KXNBAGAME-26FEB24NYKCLE-NYK`
# - YES means: New York wins (see rules_primary + yes_sub_title: 'New York')
#     - Prices:
#         - `yes_bid`/`yes_ask`: 40–41¢ (buyers at 40, sellers at 41)
#         - `no_bid`/`no_ask`: 59–60¢ (NO = “New York does not win”)
# This is basically the “Bet on NYK to win” contract.
#
# 2) `KXNBAGAME-26FEB24NYKCLE-CLE`
# - YES means: Cleveland wins (yes_sub_title: 'Cleveland')
#     - Prices:
#         - `yes_bid`/`yes_ask`: 60–62¢
#         - `no_bid`/`no_ask`: 38–40¢
# This is the “Bet on CLE to win” contract.
#
# Important intuition: These two markets are “opposites” in outcome (if one team wins, the other doesn’t), but they’re still different tickers with separate order books, so their prices/spreads/volume/open interest can differ.

# %%
# Get details for event_ticker: KXNBAGAME-26FEB24NYKCLE 

if markets_data['markets']:
    # Let's get details for the first market's event
    #event_ticker = markets_data['markets'][1]['event_ticker']
    event_ticker = 'KXNBAGAME-26FEB24NYKCLE'
    event_url = f"https://api.elections.kalshi.com/trade-api/v2/events/{event_ticker}"
    event_response = requests.get(event_url)
    event_data = event_response.json()

    print(f"Event Details:")
    print(f"Title: {event_data['event']['title']}")
    print(f"Category: {event_data['event']['category']}")
# Out:
# Event Details:
# Title: New York at Cleveland
# Category: Sports

# %% [markdown]
# ##### Get Orderbook Data
# Lets fetch the orderbook for a specific market to see the current bids and asks using the Get Market orderbook endpoint.

# %%
# Get orderbook for a specific market 'ticker': 'KXNBAGAME-26FEB24NYKCLE-NYK',
# Replace with an actual market ticker from the markets list
if not markets_data['markets']:
    raise ValueError("No open markets found. Try removing status=open or choose another series.")

# market_ticker = markets_data['markets'][0]['ticker']
market_ticker = 'KXNBAGAME-26FEB24NYKCLE-NYK'
orderbook_url = f"https://api.elections.kalshi.com/trade-api/v2/markets/{market_ticker}/orderbook"

orderbook_response = requests.get(orderbook_url)
orderbook_data = orderbook_response.json()

print(f"\nOrderbook for {market_ticker}:")
print("YES BIDS:")
for bid in orderbook_data['orderbook']['yes'][:5]:  # Show top 5
    print(f"  Price: {bid[0]}¢, Quantity: {bid[1]}")

print("\nNO BIDS:")
for bid in orderbook_data['orderbook']['no'][:5]:  # Show top 5
    print(f"  Price: {bid[0]}¢, Quantity: {bid[1]}")
# Out:
# Orderbook for KXNBAGAME-26FEB24NYKCLE-NYK:
# YES BIDS:
#   Price: 1¢, Quantity: 1437368
#   Price: 2¢, Quantity: 4900
#   Price: 3¢, Quantity: 172214
#   Price: 5¢, Quantity: 66609
#   Price: 7¢, Quantity: 38456
#
# NO BIDS:
#   Price: 1¢, Quantity: 1598477
#   Price: 2¢, Quantity: 4900
#   Price: 3¢, Quantity: 181609
#   Price: 5¢, Quantity: 72241
#   Price: 7¢, Quantity: 45006
